# %%
import numpy as np
import pandas as pd
from mlxtend.frequent_patterns import fpgrowth
from mlxtend.frequent_patterns import association_rules
import time

# %%
df = pd.read_csv('OnlineRetailShopGermany.csv')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity      InvoiceDate  UnitPrice  CustomerID  Country
# 0    536527     22809              SET OF 6 T-LIGHTS SANTA         6  12/1/2010 13:04       2.95       12662  Germany
# 1    536527     84347  ROTATING SILVER ANGELS T-LIGHT HLDR         6  12/1/2010 13:04       2.55       12662  Germany
# 2    536527     84945   MULTI COLOUR SILVER T-LIGHT HOLDER        12  12/1/2010 13:04       0.85       12662  Germany
# 3    536527     22242        5 HOOK HANGER MAGIC TOADSTOOL        12  12/1/2010 13:04       1.65       12662  Germany
# 4    536527     22244           3 HOOK HANGER MAGIC GARDEN        12  12/1/2010 13:04       1.95       12662  Germany

# %%
df.shape
# Out:
# (9495, 8)

# %%
df.dtypes
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID       int64
# Country         object
# dtype: object

# %%
print (df.isnull().values.any())
#print (df.isnull().sum())
# Out:
# False

# %%
missing_value = ["NaN", "NONE", "None", "nan", "none", "n/a", "na", " "]
df = pd.read_csv('OnlineRetailShopGermany.csv', na_values = missing_value)
print (df.isnull().sum())
# print (len(df[df.Description.isin(missing_value)]))
# df[df.Description.isin(missing_value)]
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
df['Description'] = df['Description'].str.strip() #removes spaces from beginning and end

# %%
# ranking the top 10 best-selling items
df.Description.value_counts(normalize=True)[:10]
# Out:
# POSTAGE                               0.040337
# ROUND SNACK BOXES SET OF4 WOODLAND    0.012638
# REGENCY CAKESTAND 3 TIER              0.008531
# ROUND SNACK BOXES SET OF 4 FRUITS     0.008215
# PLASTERS IN TIN WOODLAND ANIMALS      0.007056
# WOODLAND CHARLOTTE BAG                0.006214
# PLASTERS IN TIN CIRCUS PARADE         0.006003
# PLASTERS IN TIN SPACEBOY              0.005371
# 6 RIBBONS RUSTIC CHARM                0.005266
# JUMBO BAG WOODLAND ANIMALS            0.005055
# Name: Description, dtype: float64

# %%
df.drop(df[df['Description'] == 'POSTAGE'].index, inplace = True)
df.shape
# Out:
# (9112, 8)

# %%
# # Outliers
# quantile1, quantile3= np.percentile(df['Quantity'],[20,80])
# print(quantile1,quantile3)

# # IQR
# iqr_value=quantile3-quantile1
# print(iqr_value)

# # lower bound value and higher bound value
# lower_bound_val = quantile1 -(1.5 * iqr_value) 
# upper_bound_val = quantile3 +(1.5 * iqr_value)
# print(lower_bound_val,upper_bound_val)

# df['Quantity'] = np.where(df['Quantity']>=upper_bound_val, np.nan, df['Quantity'])
# df['Quantity'] = np.where(df['Quantity']<=lower_bound_val-1, np.nan, df['Quantity'])

# %%
# Select duplicate rows except first occurrence based on all columns
duplicateRows = df[df.duplicated()]
# print(duplicateRows.head())
df = df.drop_duplicates()

# %%
# create a bar chart, rank by percentage
df.Description.value_counts(normalize=True)[:30].plot(kind="bar", figsize=(10,5), title="Percentage of Sales by Item").set(xlabel="Item", ylabel="Percentage")
# Out:
# [Text(0.5, 0, 'Item'), Text(0, 0.5, 'Percentage')]

# %%
# create a bar chart, rank by value
df.Description.value_counts()[:30].plot(kind="bar", figsize=(10,5), title="Total Number of Sales by Item").set(xlabel="Item", ylabel="Total Number")
# Out:
# [Text(0.5, 0, 'Item'), Text(0, 0.5, 'Total Number')]

# %%
df2 = (df.groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

# %%
df2.head()
# Out:
# Description  10 COLOUR SPACEBOY PEN  ...  ZINC WILLIE WINKIE  CANDLE STICK
# InvoiceNo                            ...
# 536527                          0.0  ...                               0.0
# 536840                          0.0  ...                               0.0
# 536861                          0.0  ...                               0.0
# 536967                          0.0  ...                               0.0
# 536983                          0.0  ...                               0.0
#
# [5 rows x 1700 columns]

# %%
def convertToZeroOne(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

df3 = df2.applymap(convertToZeroOne)

# %%
df3.head()
# Out:
# Description  10 COLOUR SPACEBOY PEN  ...  ZINC WILLIE WINKIE  CANDLE STICK
# InvoiceNo                            ...
# 536527                            0  ...                                 0
# 536840                            0  ...                                 0
# 536861                            0  ...                                 0
# 536967                            0  ...                                 0
# 536983                            0  ...                                 0
#
# [5 rows x 1700 columns]

# %%
start_time = time.time()
frequent_itemsets = fpgrowth(df3, min_support=0.04, use_colnames=True)
end_time = time.time()
frequent_itemsets
# Out:
#      support                                           itemsets
# 0   0.078098                       (JUMBO BAG WOODLAND ANIMALS)
# 1   0.079796                           (6 RIBBONS RUSTIC CHARM)
# 2   0.071307                           (JAM MAKING SET PRINTED)
# 3   0.066214                  (PACK OF 72 RETROSPOT CAKE CASES)
# 4   0.049236                            (JAM JAR WITH PINK LID)
# 5   0.061121                          (JUMBO BAG RED RETROSPOT)
# 6   0.052632                 (WOODLAND PARTY BAG + STICKER SET)
# 7   0.044143                             (IVORY KITCHEN SCALES)
# 8   0.042445                        (MEMO BOARD COTTAGE DESIGN)
# 9   0.190153               (ROUND SNACK BOXES SET OF4 WOODLAND)
# 10  0.122241                (ROUND SNACK BOXES SET OF 4 FRUITS)
# 11  0.106961                         (REGENCY CAKESTAND 3 TIER)
# 12  0.098472                           (WOODLAND CHARLOTTE BAG)
# 13  0.089983                    (PLASTERS IN TIN CIRCUS PARADE)
# 14  0.079796                               (SPACEBOY LUNCH BOX)
# 15  0.056027                                (GUMBALL COAT RACK)
# 16  0.054329                      (RED RETROSPOT CHARLOTTE BAG)
# 17  0.050934                         (RED RETROSPOT MINI CASES)
# 18  0.047538                (RETROSPOT PARTY BAG + STICKER SET)
# 19  0.106961                 (PLASTERS IN TIN WOODLAND ANIMALS)
# 20  0.054329                                (RED RETROSPOT CUP)
# 21  0.049236                       (FAWN BLUE HOT WATER BOTTLE)
# 22  0.042445                               (RED KITCHEN SCALES)
# 23  0.074703                    (RED TOADSTOOL LED NIGHT LIGHT)
# 24  0.040747                              (MINT KITCHEN SCALES)
# 25  0.083192                         (PLASTERS IN TIN SPACEBOY)
# 26  0.061121                (STRAWBERRY LUNCH BOX WITH CUTLERY)
# 27  0.049236                 (LUNCH BOX WITH CUTLERY RETROSPOT)
# 28  0.054329                        (PLASTERS IN TIN STRONGMAN)
# 29  0.054329                        (ALARM CLOCK BAKELIKE PINK)
# 30  0.047538                 (PACK OF 20 NAPKINS PANTRY DESIGN)
# 31  0.045840                    (PACK OF 20 NAPKINS RED APPLES)
# 32  0.040747                   (STRAWBERRY CERAMIC TRINKET BOX)
# 33  0.045840                 (SET OF 3 CAKE TINS PANTRY DESIGN)
# 34  0.040747               (WHITE SPOT RED CERAMIC DRAWER KNOB)
# 35  0.044143                    (SET/6 RED SPOTTY PAPER PLATES)
# 36  0.040747                      (SET/6 RED SPOTTY PAPER CUPS)
# 37  0.044143                     (SKULL LUNCH BOX WITH CUTLERY)
# 38  0.044143               (SET/20 RED RETROSPOT PAPER NAPKINS)
# 39  0.047538                         (COFFEE MUG APPLES DESIGN)
# 40  0.061121                               (LUNCH BAG WOODLAND)
# 41  0.044143                  (RETROSPOT TEA SET CERAMIC 11 PC)
# 42  0.047538                                 (JUMBO BAG APPLES)
# 43  0.050934                      (CHARLOTTE BAG APPLES DESIGN)
# 44  0.047538                           (LUNCH BAG APPLE DESIGN)
# 45  0.054329                       (SET OF 3 REGENCY CAKE TINS)
# 46  0.044143               (SET OF 60 PANTRY DESIGN CAKE CASES)
# 47  0.101868  (ROUND SNACK BOXES SET OF4 WOODLAND, ROUND SNA...
# 48  0.049236  (ROUND SNACK BOXES SET OF4 WOODLAND, WOODLAND ...
# 49  0.044143  (ROUND SNACK BOXES SET OF4 WOODLAND, PLASTERS ...
# 50  0.052632  (PLASTERS IN TIN WOODLAND ANIMALS, PLASTERS IN...
# 51  0.054329  (SPACEBOY LUNCH BOX, ROUND SNACK BOXES SET OF4...
# 52  0.045840  (RED RETROSPOT CHARLOTTE BAG, WOODLAND CHARLOT...
# 53  0.057725  (ROUND SNACK BOXES SET OF4 WOODLAND, PLASTERS ...
# 54  0.047538  (PLASTERS IN TIN SPACEBOY, PLASTERS IN TIN WOO...

# %%
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)
rules.head()
# Out:
#                             antecedents                           consequents  ...  leverage  conviction
# 0  (ROUND SNACK BOXES SET OF4 WOODLAND)   (ROUND SNACK BOXES SET OF 4 FRUITS)  ...  0.078623    1.890558
# 1   (ROUND SNACK BOXES SET OF 4 FRUITS)  (ROUND SNACK BOXES SET OF4 WOODLAND)  ...  0.078623    4.859083
# 2  (ROUND SNACK BOXES SET OF4 WOODLAND)              (WOODLAND CHARLOTTE BAG)  ...  0.030511    1.216520
# 3              (WOODLAND CHARLOTTE BAG)  (ROUND SNACK BOXES SET OF4 WOODLAND)  ...  0.030511    1.619694
# 4  (ROUND SNACK BOXES SET OF4 WOODLAND)       (PLASTERS IN TIN CIRCUS PARADE)  ...  0.027032    1.185138
#
# [5 rows x 9 columns]

# %%
#Filtering rules based on condition
rules[(rules['lift'] >= 0.5) & (rules['confidence'] >= 0.3)]
# Out:
#                              antecedents                           consequents  ...  leverage  conviction
# 0   (ROUND SNACK BOXES SET OF4 WOODLAND)   (ROUND SNACK BOXES SET OF 4 FRUITS)  ...  0.078623    1.890558
# 1    (ROUND SNACK BOXES SET OF 4 FRUITS)  (ROUND SNACK BOXES SET OF4 WOODLAND)  ...  0.078623    4.859083
# 3               (WOODLAND CHARLOTTE BAG)  (ROUND SNACK BOXES SET OF4 WOODLAND)  ...  0.030511    1.619694
# 5        (PLASTERS IN TIN CIRCUS PARADE)  (ROUND SNACK BOXES SET OF4 WOODLAND)  ...  0.027032    1.589700
# 6     (PLASTERS IN TIN WOODLAND ANIMALS)       (PLASTERS IN TIN CIRCUS PARADE)  ...  0.043007    1.791596
# 7        (PLASTERS IN TIN CIRCUS PARADE)    (PLASTERS IN TIN WOODLAND ANIMALS)  ...  0.043007    2.151412
# 8                   (SPACEBOY LUNCH BOX)  (ROUND SNACK BOXES SET OF4 WOODLAND)  ...  0.039156    2.537521
# 10         (RED RETROSPOT CHARLOTTE BAG)              (WOODLAND CHARLOTTE BAG)  ...  0.040490    5.769779
# 11              (WOODLAND CHARLOTTE BAG)         (RED RETROSPOT CHARLOTTE BAG)  ...  0.040490    1.769319
# 12  (ROUND SNACK BOXES SET OF4 WOODLAND)    (PLASTERS IN TIN WOODLAND ANIMALS)  ...  0.037386    1.282312
# 13    (PLASTERS IN TIN WOODLAND ANIMALS)  (ROUND SNACK BOXES SET OF4 WOODLAND)  ...  0.037386    1.759323
# 14            (PLASTERS IN TIN SPACEBOY)    (PLASTERS IN TIN WOODLAND ANIMALS)  ...  0.038640    2.083758
# 15    (PLASTERS IN TIN WOODLAND ANIMALS)            (PLASTERS IN TIN SPACEBOY)  ...  0.038640    1.650255
#
# [13 rows x 9 columns]

# %%
# Import seaborn under its standard alias
import seaborn as sns
import matplotlib.pyplot as plt


# Generate scatterplot using support and confidence
sns.scatterplot(x = "support", y = "confidence", 
                size = "lift", data = rules)
plt.show()

# %%
print(end_time-start_time)
# Out:
# 0.037897586822509766
