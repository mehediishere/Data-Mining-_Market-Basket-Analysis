# %%
import pyfpgrowth
import time
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('OnlineRetailShopGermany.csv')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536527     22809              SET OF 6 T-LIGHTS SANTA         6
# 1    536527     84347  ROTATING SILVER ANGELS T-LIGHT HLDR         6
# 2    536527     84945   MULTI COLOUR SILVER T-LIGHT HOLDER        12
# 3    536527     22242        5 HOOK HANGER MAGIC TOADSTOOL        12
# 4    536527     22244           3 HOOK HANGER MAGIC GARDEN        12
#
#        InvoiceDate  UnitPrice  CustomerID  Country
# 0  12/1/2010 13:04       2.95       12662  Germany
# 1  12/1/2010 13:04       2.55       12662  Germany
# 2  12/1/2010 13:04       0.85       12662  Germany
# 3  12/1/2010 13:04       1.65       12662  Germany
# 4  12/1/2010 13:04       1.95       12662  Germany

# %%
df.shape
# Out:
# (9495, 8)

# %%
df.dtypes
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID       int64
# Country         object
# dtype: object

# %%
print (df.isnull().values.any())
#print (df.isnull().sum())
# Out:
# False

# %%
missing_value = ["NaN", "NONE", "None", "nan", "none", "n/a", "na", " "]
df = pd.read_csv('OnlineRetailShopGermany.csv', na_values = missing_value)
print (df.isnull().sum())
# print (len(df[df.Description.isin(missing_value)]))
# df[df.Description.isin(missing_value)]
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
df['Description'] = df['Description'].str.strip() #removes spaces from beginning and end

# %%
# ranking the top 10 best-selling items
df.Description.value_counts(normalize=True)[:10]
# Out:
# POSTAGE                               0.040337
# ROUND SNACK BOXES SET OF4 WOODLAND    0.012638
# REGENCY CAKESTAND 3 TIER              0.008531
# ROUND SNACK BOXES SET OF 4 FRUITS     0.008215
# PLASTERS IN TIN WOODLAND ANIMALS      0.007056
# WOODLAND CHARLOTTE BAG                0.006214
# PLASTERS IN TIN CIRCUS PARADE         0.006003
# PLASTERS IN TIN SPACEBOY              0.005371
# 6 RIBBONS RUSTIC CHARM                0.005266
# JUMBO BAG WOODLAND ANIMALS            0.005055
# Name: Description, dtype: float64

# %%
df.drop(df[df['Description'] == 'POSTAGE'].index, inplace = True)
df.shape
# Out:
# (9112, 8)

# %%
# Select duplicate rows except first occurrence based on all columns
duplicateRows = df[df.duplicated()]
# print(duplicateRows.head())
df = df.drop_duplicates()

# %%
# create a bar chart, rank by percentage
df.Description.value_counts(normalize=True)[:30].plot(kind="bar", figsize=(10,5), title="Percentage of Sales by Item").set(xlabel="Item", ylabel="Percentage")
# Out:
# [Text(0.5, 0, 'Item'), Text(0, 0.5, 'Percentage')]

# %%
# create a bar chart, rank by value
df.Description.value_counts()[:30].plot(kind="bar", figsize=(10,5), title="Total Number of Sales by Item").set(xlabel="Item", ylabel="Total Number")
# Out:
# [Text(0.5, 0, 'Item'), Text(0, 0.5, 'Total Number')]

# %%
# Create transactions for each of the InvoiceNo.

grouped_df = df.groupby(by = ['InvoiceNo'])

transactions = []
for group, pdf in grouped_df:
    transactions.append(pdf['Description'].tolist())
    
transactions
# Out:
# [['SET OF 6 T-LIGHTS SANTA',
#   'ROTATING SILVER ANGELS T-LIGHT HLDR',
#   'MULTI COLOUR SILVER T-LIGHT HOLDER',
#   '5 HOOK HANGER MAGIC TOADSTOOL',
#   '3 HOOK HANGER MAGIC GARDEN',
#   '5 HOOK HANGER RED MAGIC TOADSTOOL',
#   'ASSORTED COLOUR LIZARD SUCTION HOOK',
#   'JUMBO BAG WOODLAND ANIMALS',
#   'JUMBO BAG OWLS',
#   'HOT WATER BOTTLE BABUSHKA',
#   'HOMEMADE JAM SCENTED CANDLES',
#   "CHILDREN'S CIRCUS PARADE MUG",
#   'PACK 3 FIRE ENGINE/CAR PATCHES',
#   'PICTURE DOMINOES'],
#  ['JAM MAKING SET PRINTED',
#   'JAM JAR WITH PINK LID',
#   'JAM JAR WITH GREEN LID',
#   'SWEETHEART CAKESTAND 3 TIER',
#   '60 CAKE CASES VINTAGE CHRISTMAS',
#   '6 RIBBONS RUSTIC CHARM',
#   'CAKE STAND WHITE TWO TIER LACE',
#   'PACK OF 60 PINK PAISLEY CAKE CASES',
#   '60 TEATIME FAIRY CAKE CASES',
#   'PACK OF 72 RETROSPOT CAKE CASES'],
#  ['FELTCRAFT 6 FLOWER FRIENDS',
#   '6 RIBBONS RUSTIC CHARM',
#   'WOODLAND  HEIGHT CHART STICKERS',
#   'CHILDS BREAKFAST SET CIRCUS PARADE',
#   'CHILDS BREAKFAST SET SPACEBOY',
#   'COFFEE MUG CAT + BIRD DESIGN',
#   'COFFEE MUG DOG + BALL DESIGN',
#   'BALLOONS  WRITING SET',
#   'DINOSAURS  WRITING SET'],
#  ['JUMBO BAG RED RETROSPOT'],
#  ['WOODLAND PARTY BAG + STICKER SET',
#   'HAND WARMER OWL DESIGN',
#   '3 HOOK PHOTO SHELF ANTIQUE WHITE',
#   'IVORY GIANT GARDEN THERMOMETER',
#   'BLUE COAT RACK PARIS FASHION',
#   'HOT BATHS SOAP HOLDER',
#   'PENCIL CASE LIFE IS BEAUTIFUL',
#   'LARGE CHINESE STYLE SCISSOR'],
#  ['BISCUIT TIN VINTAGE GREEN',
#   'BISCUIT TIN VINTAGE RED',
#   'JAM MAKING SET PRINTED',
#   'JAM JAR WITH PINK LID',
#   'JAM JAR WITH GREEN LID',
#   'PINK 3 PIECE POLKADOT CUTLERY SET',
#   'FRYING PAN RED RETROSPOT',
#   'FRYING PAN PINK POLKADOT',
#   'MEMO BOARD COTTAGE DESIGN',
#   'MEMO BOARD RETROSPOT  DESIGN',
#   'PINK HEART SHAPE EGG FRYING PAN',
#   'FRENCH ENAMEL UTENSIL HOLDER',
#   'SET OF 16 VINTAGE ROSE CUTLERY',
#   'IVORY KITCHEN SCALES',
#   'ROUND CAKE TIN VINTAGE GREEN',
#   'BREAD BIN DINER STYLE IVORY'],
#  ['DOORMAT RED RETROSPOT'],
#  ['GUMBALL MAGAZINE RACK',
#   'HAND WARMER OWL DESIGN',
#   'JAM MAKING SET WITH JARS',
#   'JAM MAKING SET PRINTED',
#   'JAM JAR WITH PINK LID',
#   'JAM JAR WITH GREEN LID',
#   '3 PIECE SPACEBOY COOKIE CUTTER SET',
#   "CHILDREN'S SPACEBOY MUG",
#   "CHILDREN'S CIRCUS PARADE MUG",
#   'SPACEBOY CHILDRENS EGG CUP',
#   'CIRCUS PARADE CHILDRENS EGG CUP',
#   'HAND WARMER BABUSHKA DESIGN',
#   'FELTCRAFT CUSHION OWL',
#   'SET OF 20 KIDS COOKIE CUTTERS',
#   'FELTCRAFT CHRISTMAS FAIRY',
#   'CHILDRENS APRON APPLES DESIGN',
#   'HOT WATER BOTTLE BABUSHKA',
#   'ROSE COTTAGE KEEPSAKE BOX',
#   'CARD MOTORBIKE SANTA',
#   'CARD CHRISTMAS VILLAGE',
#   'RED  HARMONICA IN BOX',
#   'BLUE HARMONICA IN BOX',
#   'RETROSPOT PARTY BAG + STICKER SET',
#   'DISCO BALL CHRISTMAS DECORATION',
#   'GLITTER CHRISTMAS TREE',
#   'ANGEL DECORATION PAINTED ZINC',
#   'ROCKING HORSE RED CHRISTMAS',
#   'ROCKING HORSE GREEN CHRISTMAS',
#   'WOODEN TREE CHRISTMAS SCANDINAVIAN',
#   'CHRISTMAS RETROSPOT ANGEL WOOD',
#   'SMALL PINK MAGIC CHRISTMAS TREE',
#   'SPACEBOY LUNCH BOX',
#   'ROUND SNACK BOXES SET OF4 WOODLAND',
#   'WOODLAND CHARLOTTE BAG',
#   'PLASTERS IN TIN CIRCUS PARADE',
#   'SET OF 2 TEA TOWELS APPLE AND PEARS',
#   'RED RETROSPOT MINI CASES',
#   'BIRD DECORATION RED RETROSPOT',
#   'RETROSPOT PADDED SEAT CUSHION',
#   '6 RIBBONS RUSTIC CHARM',
#   'SCANDINAVIAN REDS RIBBONS',
#   'BRIGHT BLUES RIBBONS',
#   'BABY BOOM RIBBONS',
#   'CHOCOLATE BOX RIBBONS',
#   'CHRISTMAS CRAFT TREE TOP ANGEL',
#   'CHRISTMAS CRAFT LITTLE FRIENDS',
#   'CHRISTMAS RETROSPOT HEART WOOD',
#   'CHRISTMAS RETROSPOT STAR WOOD',
#   'CHRISTMAS GINGHAM HEART',
#   'CHRISTMAS GINGHAM TREE',
#   'CHRISTMAS GINGHAM STAR',
#   'STAR WOODEN CHRISTMAS DECORATION',
#   'HEART WOODEN CHRISTMAS DECORATION',
#   'WOODEN HEART CHRISTMAS SCANDINAVIAN',
#   'WOODEN STAR CHRISTMAS SCANDINAVIAN',
#   'RED RETROSPOT CHARLOTTE BAG',
#   'REGENCY CAKESTAND 3 TIER',
#   'ROUND SNACK BOXES SET OF 4 FRUITS',
#   'CIRCUS PARADE LUNCH BOX',
#   'RIBBON REEL POLKADOTS',
#   'RIBBON REEL HEARTS DESIGN',
#   'RIBBON REEL LACE DESIGN',
#   'HAND WARMER BIRD DESIGN',
#   'GUMBALL COAT RACK',
#   '5 HOOK HANGER MAGIC TOADSTOOL',
#   '3 HOOK HANGER MAGIC GARDEN',
#   'HOOK, 1 HANGER ,MAGIC GARDEN',
#   'SET/5 RED RETROSPOT LID GLASS BOWLS',
#   'CHILDS BREAKFAST SET CIRCUS PARADE'],
#  ['JUMBO BAG WOODLAND ANIMALS',
#   'WOODLAND CHARLOTTE BAG',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'PACK OF 12 WOODLAND TISSUES',
#   'JAM MAKING SET WITH JARS',
#   'JAM MAKING SET PRINTED',
#   'JAM JAR WITH PINK LID',
#   'JAM JAR WITH GREEN LID',
#   'PACK OF 12 PINK PAISLEY TISSUES',
#   'STARS GIFT TAPE',
#   'PLASTERS IN TIN VINTAGE PAISLEY',
#   'SMALL POPCORN HOLDER',
#   'PARTY PIZZA DISH GREEN POLKADOT',
#   'PARTY PIZZA DISH PINK POLKADOT',
#   'PARTY PIZZA DISH BLUE POLKADOT',
#   'FELTCRAFT 6 FLOWER FRIENDS',
#   'RED KITCHEN SCALES',
#   'IVORY KITCHEN SCALES',
#   'SCOTTIE DOG HOT WATER BOTTLE',
#   'FAWN BLUE HOT WATER BOTTLE',
#   'PINK FLOWER FABRIC PONY',
#   'SET/3 RED GINGHAM ROSE STORAGE BOX',
#   'PINK POLKADOT BOWL',
#   'PINK  POLKADOT PLATE',
#   'RED RETROSPOT SHOPPER BAG',
#   'JUMBO BAG PINK POLKADOT',
#   'JUMBO BAG RED RETROSPOT',
#   'RED RETROSPOT CUP',
#   'PINK  POLKADOT CUP'],
#  ['ENGLISH ROSE HOT WATER BOTTLE',
#   'SET 3 RETROSPOT TEA,COFFEE,SUGAR',
#   'ROUND SNACK BOXES SET OF4 WOODLAND',
#   'BLUE POLKADOT BOWL',
#   'BLUE POLKADOT CUP',
#   'RED RETROSPOT BOWL',
#   'RED RETROSPOT CUP',
#   'RED RETROSPOT PLATE',
#   'BLUE POLKADOT PLATE',
#   'GUMBALL COAT RACK',
#   'RIBBON REEL STRIPES DESIGN',
#   'ROUND SNACK BOXES SET OF 4 FRUITS',
#   'CHICK GREY HOT WATER BOTTLE'],
#  ['SET OF 16 VINTAGE PISTACHIO CUTLERY',
#   'SET OF 16 VINTAGE ROSE CUTLERY',
#   'BREAD BIN DINER STYLE RED',
#   'BREAD BIN DINER STYLE IVORY',
#   'TEA TIME OVEN GLOVE',
#   '3 HOOK HANGER MAGIC GARDEN',
#   'FRYING PAN RED RETROSPOT',
#   'FRYING PAN PINK POLKADOT',
#   'SET/2 RED RETROSPOT TEA TOWELS',
#   'MILK PAN RED RETROSPOT',
#   'MILK PAN PINK POLKADOT',
#   'RED TOADSTOOL LED NIGHT LIGHT',
#   'IVORY KITCHEN SCALES',
#   'KIDS RAIN MAC PINK',
#   'TOADSTOOL MONEY BOX',
#   'SET OF 6 STRAWBERRY CHOPSTICKS'],
#  ['RED GINGHAM ROSE JEWELLERY BOX',
#   'GUMBALL COAT RACK',
#   'RED KITCHEN SCALES',
#   'MINT KITCHEN SCALES',
#   'SCANDINAVIAN REDS RIBBONS',
#   '36 PENCILS TUBE RED RETROSPOT'],
#  ['BABUSHKA LIGHTS STRING OF 10',
#   'CHILDS BREAKFAST SET CIRCUS PARADE',
#   'SET 12 KIDS COLOUR  CHALK STICKS',
#   'VINTAGE HEADS AND TAILS CARD GAME',
#   '4 TRADITIONAL SPINNING TOPS',
#   'PLASTERS IN TIN CIRCUS PARADE',
#   'RETROSPOT CHILDRENS APRON',
#   'ROUND SNACK BOXES SET OF4 WOODLAND',
#   'ROUND SNACK BOXES SET OF 4 FRUITS'],
#  ['CHRISTMAS LIGHTS 10 VINTAGE BAUBLES',
#   '3 PIECE SPACEBOY COOKIE CUTTER SET',
#   "CHILDREN'S SPACEBOY MUG",
#   'PLASTERS IN TIN SPACEBOY',
#   'WOODLAND  STICKERS',
#   'WOODLAND PARTY BAG + STICKER SET',
#   'ROUND SNACK BOXES SET OF4 WOODLAND',
#   'ALARM CLOCK BAKELIKE IVORY',
#   'ALARM CLOCK BAKELIKE RED',
#   'ALARM CLOCK BAKELIKE CHOCOLATE',
#   'TEA FOR ONE POLKADOT',
#   'BROCADE RING PURSE',
#   'PACK OF 6 BIRDY GIFT TAGS'],
#  ['METAL 4 HOOK HANGER FRENCH CHATEAU',
#   '3 HOOK PHOTO SHELF ANTIQUE WHITE',
#   '12 PENCIL SMALL TUBE WOODLAND',
#   'FAWN BLUE HOT WATER BOTTLE',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY',
#   'LUNCH BOX WITH CUTLERY RETROSPOT',
#   'HOLIDAY FUN LUDO',
#   'WOODEN FRAME ANTIQUE WHITE',
#   'BROCANTE COAT RACK',
#   'PINK PADDED MOBILE'],
#  ['SET OF 72 RETROSPOT PAPER  DOILIES',
#   'PACK OF 72 RETROSPOT CAKE CASES',
#   'WOODLAND DESIGN  COTTON TOTE BAG',
#   'BIG DOUGHNUT FRIDGE MAGNETS',
#   'RECYCLED PENCIL WITH RABBIT ERASER',
#   'RED TOADSTOOL LED NIGHT LIGHT',
#   'RAIN PONCHO RETROSPOT',
#   'STRAWBERRY CERAMIC TRINKET BOX',
#   '6 RIBBONS RUSTIC CHARM',
#   'ROUND SNACK BOXES SET OF4 WOODLAND',
#   'REGENCY CAKESTAND 3 TIER',
#   'TV DINNER TRAY DOLLY GIRL',
#   'PENCIL CASE LIFE IS BEAUTIFUL',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'PLASTERS IN TIN CIRCUS PARADE',
#   'PLASTERS IN TIN STRONGMAN',
#   'CERAMIC STRAWBERRY CAKE MONEY BANK',
#   'CERAMIC CHERRY CAKE MONEY BANK',
#   'STRAWBERRY FAIRY CAKE TEAPOT',
#   'PACK OF 12 TRADITIONAL CRAYONS',
#   'PACK OF 20 NAPKINS PANTRY DESIGN',
#   'PACK OF 20 NAPKINS RED APPLES',
#   'OVEN MITT APPLES DESIGN',
#   'SET 7 BABUSHKA NESTING BOXES',
#   'BREAD BIN DINER STYLE PINK',
#   'ALARM CLOCK BAKELIKE PINK',
#   'HEN HOUSE W CHICK STANDING',
#   'ROSE COTTAGE KEEPSAKE BOX',
#   'PACK OF 12 COLOURED PENCILS',
#   'FUNKY DIVA PEN',
#   'CHEST OF DRAWERS GINGHAM HEART',
#   'TRADITIONAL KNITTING NANCY',
#   'BAKING MOULD CHOCOLATE CUPCAKES',
#   "POPPY'S PLAYHOUSE LIVINGROOM",
#   "POPPY'S PLAYHOUSE BEDROOM",
#   "POPPY'S PLAYHOUSE KITCHEN",
#   'LIPSTICK PEN RED',
#   'SET OF 3 NOTEBOOKS IN PARCEL',
#   'PICTURE DOMINOES',
#   'RED KITCHEN SCALES',
#   'SWEETHEART CERAMIC TRINKET BOX',
#   'SAVE THE PLANET COTTON TOTE BAG',
#   'SET OF 6 T-LIGHTS EASTER CHICKS',
#   'ASSORTED EASTER DECORATIONS  BELLS',
#   'EASTER TIN BUNNY BOUQUET',
#   'BAKING MOULD EASTER EGG WHITE CHOC'],
#  ['CHILDS BREAKFAST SET CIRCUS PARADE', 'GLASS  BEURRE DISH'],
#  ['VINTAGE BEAD PINK SCARF',
#   'FAWN BLUE HOT WATER BOTTLE',
#   'EDWARDIAN PARASOL RED',
#   'RED RETROSPOT UMBRELLA'],
#  ['RED COAT RACK PARIS FASHION',
#   'FRIDGE MAGNETS LES ENFANTS ASSORTED',
#   'HOMEMADE JAM SCENTED CANDLES',
#   'JAM JAR WITH PINK LID',
#   'JAM MAKING SET PRINTED',
#   '3 PIECE SPACEBOY COOKIE CUTTER SET',
#   'GINGERBREAD MAN COOKIE CUTTER',
#   'MAKE YOUR OWN FLOWERPOWER CARD KIT',
#   'MAKE YOUR OWN MONSOON CARD KIT',
#   'SAVE THE PLANET COTTON TOTE BAG',
#   'WOODLAND DESIGN  COTTON TOTE BAG',
#   'BIG DOUGHNUT FRIDGE MAGNETS',
#   'RED TOADSTOOL LED NIGHT LIGHT',
#   'REGENCY CAKESTAND 3 TIER',
#   'ROUND SNACK BOXES SET OF4 WOODLAND',
#   'TV DINNER TRAY DOLLY GIRL',
#   'PENCIL CASE LIFE IS BEAUTIFUL',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'PLASTERS IN TIN STRONGMAN',
#   'PLASTERS IN TIN CIRCUS PARADE',
#   'RED KITCHEN SCALES',
#   'STRAWBERRY FAIRY CAKE TEAPOT',
#   'BREAD BIN DINER STYLE PINK',
#   'ALARM CLOCK BAKELIKE PINK',
#   'ROSE COTTAGE KEEPSAKE BOX',
#   'SET 7 BABUSHKA NESTING BOXES'],
#  ['SET OF 3 CAKE TINS PANTRY DESIGN'],
#  ['RETROSPOT HEART HOT WATER BOTTLE',
#   'VICTORIAN SEWING BOX LARGE',
#   'PARTY PIZZA DISH RED RETROSPOT',
#   'CABIN BAG VINTAGE RETROSPOT',
#   'CABIN BAG VINTAGE PAISLEY',
#   'SET/10 PINK POLKADOT PARTY CANDLES',
#   'DOORMAT RED RETROSPOT'],
#  ['SET OF 6 SPICE TINS PANTRY DESIGN',
#   '5 HOOK HANGER RED MAGIC TOADSTOOL',
#   'SET OF SALT AND PEPPER TOADSTOOLS',
#   'KIDS RAIN MAC PINK',
#   'RED KITCHEN SCALES',
#   'SALLE DE BAIN HOOK',
#   'MEASURING TAPE BABUSHKA PINK',
#   'ROSE COTTAGE KEEPSAKE BOX',
#   'MEMO BOARD COTTAGE DESIGN',
#   'BLACK KITCHEN SCALES'],
#  ['JAM MAKING SET WITH JARS',
#   'JAM MAKING SET PRINTED',
#   "CHILDREN'S CIRCUS PARADE MUG",
#   'CUTE CATS TAPE',
#   '6 RIBBONS SHIMMERING PINKS',
#   'LOCAL CAFE MUG',
#   'HAND WARMER BABUSHKA DESIGN',
#   'CHARLOTTE BAG SUKI DESIGN',
#   'PINK FELT EASTER RABBIT GARLAND',
#   'TRAVEL SEWING KIT',
#   'DELUXE SEWING KIT',
#   '6 RIBBONS RUSTIC CHARM',
#   'REGENCY CAKESTAND 3 TIER',
#   '12 PENCIL SMALL TUBE WOODLAND',
#   'SET 7 BABUSHKA NESTING BOXES',
#   'HOT WATER BOTTLE BABUSHKA',
#   'CHILDS BREAKFAST SET CIRCUS PARADE'],
#  ['SET OF 3 CAKE TINS PANTRY DESIGN',
#   'SET OF 3 CAKE TINS SKETCHBOOK',
#   'SET OF 6 SPICE TINS PANTRY DESIGN',
#   'SET OF 6 HERB TINS SKETCHBOOK',
#   'RED RETROSPOT TAPE',
#   'PARTY PIZZA DISH RED RETROSPOT',
#   'PARTY PIZZA DISH PINK POLKADOT',
#   'PARTY PIZZA DISH BLUE POLKADOT',
#   'PARTY PIZZA DISH GREEN POLKADOT',
#   '12 PENCIL SMALL TUBE WOODLAND',
#   'RECYCLING BAG RETROSPOT',
#   'RED RETROSPOT CHARLOTTE BAG',
#   'CAKES AND BOWS GIFT  TAPE',
#   'STARS GIFT TAPE'],
#  ['HAND WARMER BABUSHKA DESIGN',
#   'PINK STITCHED WALL CLOCK',
#   'MAGIC SHEEP WOOL GROWING FROM PAPER',
#   'LOVE HEART POCKET WARMER',
#   'FLYING PIG WATERING CAN',
#   'BLACK STITCHED WALL CLOCK',
#   'WHITE STITCHED WALL CLOCK',
#   'HOT WATER BOTTLE BABUSHKA',
#   'FAWN BLUE HOT WATER BOTTLE',
#   'GREY HEART HOT WATER BOTTLE',
#   'ENGLISH ROSE HOT WATER BOTTLE',
#   'FELT TOADSTOOL LARGE',
#   'FELT TOADSTOOL  SMALL',
#   'ROUND SNACK BOXES SET OF4 WOODLAND',
#   'ROUND SNACK BOXES SET OF 4 FRUITS',
#   'LUNCH BOX I LOVE LONDON',
#   'WOODLAND STORAGE BOX SMALL',
#   'WOODLAND STORAGE BOX LARGE',
#   'RED TOADSTOOL LED NIGHT LIGHT',
#   'JUMBO BAG WOODLAND ANIMALS',
#   'STRAWBERRY CERAMIC TRINKET BOX',
#   'SWEETHEART CERAMIC TRINKET BOX',
#   'SET OF SALT AND PEPPER TOADSTOOLS',
#   'REGENCY CAKESTAND 3 TIER',
#   'CAKE STAND LOVEBIRD 2 TIER PINK',
#   'CAKE STAND 3 TIER MAGIC GARDEN',
#   'CAKE PLATE LOVEBIRD PINK',
#   'CAKE PLATE LOVEBIRD WHITE',
#   'SAVE THE PLANET MUG'],
#  ['RED RETROSPOT TAPE',
#   'CUTE CATS TAPE',
#   'CAKES AND BOWS GIFT  TAPE',
#   'METAL SIGN HER DINNER IS SERVED',
#   'WALL TIDY RETROSPOT',
#   'MAGNETS PACK OF 4 RETRO PHOTO',
#   'METAL SIGN,CUPCAKE SINGLE HOOK',
#   'METAL SIGN CUPCAKE SINGLE HOOK',
#   'SET OF 4 FAIRY CAKE PLACEMATS',
#   'SWEETHEART CERAMIC TRINKET BOX',
#   'STRAWBERRY CERAMIC TRINKET BOX',
#   'PINK DOUGHNUT TRINKET POT',
#   'CERAMIC CHERRY CAKE MONEY BANK',
#   'CERAMIC CAKE DESIGN SPOTTED MUG',
#   'TEA TIME KITCHEN APRON',
#   'TEA TIME TABLE CLOTH',
#   'DOORMAT FAIRY CAKE',
#   'SET/5 RED RETROSPOT LID GLASS BOWLS',
#   'SET/2 RED RETROSPOT TEA TOWELS',
#   'RED RETROSPOT TRADITIONAL TEAPOT',
#   'BEWARE OF THE CAT METAL SIGN',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'RED TOADSTOOL LED NIGHT LIGHT'],
#  ['JAM MAKING SET PRINTED',
#   'JAM JAR WITH GREEN LID',
#   'JAM JAR WITH PINK LID',
#   'BREAD BIN DINER STYLE MINT',
#   'BREAD BIN DINER STYLE IVORY',
#   'IVORY KITCHEN SCALES',
#   'MINT KITCHEN SCALES',
#   'PENCIL CASE LIFE IS BEAUTIFUL',
#   'WOODLAND  STICKERS',
#   'SOAP DISH BROCANTE',
#   'TRAVEL SEWING KIT'],
#  ['ROUND SNACK BOXES SET OF4 WOODLAND',
#   'JUMBO BAG WOODLAND ANIMALS',
#   '12 PENCILS TALL TUBE WOODLAND',
#   'WOODLAND PARTY BAG + STICKER SET',
#   'RETROSPOT PARTY BAG + STICKER SET',
#   'RED POLKADOT COFFEE  MUG',
#   'RED POLKADOT PUDDING BOWL',
#   'RED POLKADOT BEAKER'],
#  ['BAKING SET 9 PIECE RETROSPOT',
#   'ASSORTED COLOUR BIRD ORNAMENT',
#   'PAINTED METAL PEARS ASSORTED',
#   'WOODEN CROQUET GARDEN SET',
#   'WOODEN SKITTLES GARDEN SET',
#   'GLASS CLOCHE LARGE',
#   'GLASS CLOCHE SMALL',
#   'MULTI COLOUR SILVER T-LIGHT HOLDER',
#   'GIN + TONIC DIET METAL SIGN',
#   'HAND OVER THE CHOCOLATE   SIGN',
#   'METAL DECORATION NAUGHTY CHILDREN',
#   'MAGNETS PACK OF 4 SWALLOWS',
#   'MAGNETS PACK OF 4 CHILDHOOD MEMORY',
#   'MAGNETS PACK OF 4 HOME SWEET HOME',
#   '20 DOLLY PEGS RETROSPOT',
#   'CLOTHES PEGS RETROSPOT PACK 24',
#   'RED STRIPE CERAMIC DRAWER KNOB',
#   'BLUE STRIPE CERAMIC DRAWER KNOB',
#   'WHITE SPOT RED CERAMIC DRAWER KNOB',
#   'WHITE SPOT BLUE CERAMIC DRAWER KNOB',
#   'PINK DRAWER KNOB ACRYLIC EDWARDIAN',
#   'GREEN DRAWER KNOB ACRYLIC EDWARDIAN',
#   'BLUE DRAWER KNOB ACRYLIC EDWARDIAN',
#   'SQUARECUSHION COVER PINK UNION FLAG',
#   'CUSHION COVER PINK UNION JACK',
#   'SET OF 4 NAPKIN CHARMS CROWNS',
#   'SET OF 4 NAPKIN CHARMS 3 KEYS',
#   'SET OF 4 NAPKIN CHARMS CUTLERY',
#   '200 BENDY SKULL STRAWS',
#   '60 TEATIME FAIRY CAKE CASES',
#   '60 CAKE CASES DOLLY GIRL DESIGN',
#   'PACK OF 72 RETROSPOT CAKE CASES',
#   'PACK OF 60 DINOSAUR CAKE CASES',
#   'PACK OF 72 SKULL CAKE CASES',
#   'SET OF 36 TEATIME PAPER DOILIES',
#   '36 DOILIES DOLLY GIRL',
#   'SET OF 72 RETROSPOT PAPER  DOILIES',
#   'SET OF 72 PINK HEART PAPER DOILIES',
#   'SET OF 72 SKULL PAPER  DOILIES',
#   'SET OF 36 DINOSAUR PAPER DOILIES',
#   'REGENCY CAKESTAND 3 TIER',
#   'SET OF 3 CAKE TINS PANTRY DESIGN',
#   'JAM MAKING SET PRINTED',
#   'VINTAGE UNION JACK CUSHION COVER',
#   'VINTAGE UNION JACK APRON',
#   'EMPIRE TISSUE BOX',
#   '6 RIBBONS EMPIRE',
#   'SET 20 NAPKINS FAIRY CAKES DESIGN',
#   'GLITTER BUTTERFLY CLIPS',
#   'PACK OF 12 LONDON TISSUES',
#   'PACK OF 12 SKULL TISSUES',
#   'PACK OF 12 SUKI TISSUES',
#   'EMPIRE GIFT WRAP',
#   'TEA PARTY  WRAPPING PAPER',
#   'BIRTHDAY BANQUET GIFT WRAP',
#   'WRAP PINK FAIRY CAKES',
#   'WRAP COWBOYS',
#   'PINK BLUE FELT CRAFT TRINKET BOX',
#   'FELTCRAFT DOLL MARIA',
#   'FELTCRAFT PRINCESS OLIVIA DOLL',
#   'MAGIC DRAWING SLATE BAKE A CAKE',
#   'MAGIC DRAWING SLATE SPACEBOY',
#   'CHILDS BREAKFAST SET SPACEBOY',
#   'PLASTERS IN TIN STRONGMAN'],
#  ['SET/4 WHITE RETRO STORAGE CUBES',
#   'PINK POLKADOT CHILDRENS UMBRELLA',
#   'RED RETROSPOT CHILDRENS UMBRELLA',
#   'JUMBO BAG PINK POLKADOT',
#   'JUMBO BAG RED RETROSPOT',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES',
#   'RED 3 PIECE RETROSPOT CUTLERY SET',
#   'RED TOADSTOOL LED NIGHT LIGHT',
#   'TOADSTOOL MONEY BOX',
#   'ROSE COTTAGE KEEPSAKE BOX',
#   'PAPER BUNTING RETROSPOT'],
#  ['RED RETROSPOT TAPE',
#   'STARS GIFT TAPE',
#   'RAIN PONCHO RETROSPOT',
#   'POLKADOT RAIN HAT',
#   'VICTORIAN GLASS HANGING T-LIGHT',
#   'RIDGED GLASS POSY VASE',
#   'BAKING SET 9 PIECE RETROSPOT',
#   'PEG BAG APPLES DESIGN',
#   'CLOTHES PEGS RETROSPOT PACK 24',
#   'ROUND SNACK BOXES SET OF4 WOODLAND',
#   'ROUND SNACK BOXES SET OF 4 FRUITS',
#   'MILK PAN RED RETROSPOT',
#   'OVEN MITT APPLES DESIGN',
#   'SET OF 2 TEA TOWELS APPLE AND PEARS',
#   'SET OF SALT AND PEPPER TOADSTOOLS',
#   'CAKE STAND WHITE TWO TIER LACE',
#   'PACK OF 20 NAPKINS PANTRY DESIGN',
#   'PACK OF 20 NAPKINS RED APPLES',
#   'TABLECLOTH RED APPLES DESIGN',
#   'PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN CIRCUS PARADE',
#   'PACK OF 12 WOODLAND TISSUES',
#   'GINGHAM ROSE WRAP'],
#  ['CHARLOTTE BAG DOLLY GIRL DESIGN',
#   'WOODLAND CHARLOTTE BAG',
#   'RED RETROSPOT CHARLOTTE BAG',
#   'RETROSPOT PARTY BAG + STICKER SET',
#   'RED RETROSPOT SHOPPER BAG',
#   'RED RETROSPOT PURSE',
#   'RED RETROSPOT UMBRELLA',
#   'EDWARDIAN PARASOL RED',
#   'EDWARDIAN PARASOL BLACK',
#   'EDWARDIAN PARASOL NATURAL',
#   'SET/10 RED POLKADOT PARTY CANDLES',
#   'SET OF 6 GIRLS CELEBRATION CANDLES',
#   'SET 6 FOOTBALL CELEBRATION CANDLES',
#   'PINK BABY BUNTING',
#   'PINK PADDED MOBILE',
#   'HAIRCLIPS FORTIES FABRIC ASSORTED',
#   'RED RETROSPOT APRON',
#   'RETROSPOT CHILDRENS APRON',
#   'LARGE HEART MEASURING SPOONS',
#   'BAKING SET 9 PIECE RETROSPOT',
#   'BAKING SET SPACEBOY DESIGN',
#   'PACK OF 72 RETROSPOT CAKE CASES',
#   'FRYING PAN RED RETROSPOT',
#   'SKULL LUNCH BOX WITH CUTLERY',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY',
#   'ROUND SNACK BOXES SET OF 4 SKULLS',
#   'ROUND SNACK BOXES SET OF 4 FRUITS',
#   'RED RETROSPOT BUTTER DISH',
#   'GREEN 3 PIECE POLKADOT CUTLERY SET',
#   'RED 3 PIECE RETROSPOT CUTLERY SET',
#   'BLUE 3 PIECE POLKADOT CUTLERY SET',
#   'PINK 3 PIECE POLKADOT CUTLERY SET',
#   'CHILDS BREAKFAST SET SPACEBOY',
#   'CHILDS BREAKFAST SET DOLLY GIRL',
#   'CHILDS BREAKFAST SET CIRCUS PARADE',
#   'RED RETROSPOT CUP',
#   'PINK  POLKADOT CUP',
#   'BLUE POLKADOT CUP',
#   'RED RETROSPOT PLATE',
#   'PINK  POLKADOT PLATE',
#   'BLUE POLKADOT PLATE',
#   'GREEN POLKADOT PLATE',
#   'GREEN POLKADOT BOWL',
#   'BLUE POLKADOT BOWL',
#   'RED RETROSPOT BOWL',
#   'PINK POLKADOT BOWL',
#   'SET/5 RED RETROSPOT LID GLASS BOWLS',
#   'BLUE  VOILE LAMPSHADE',
#   'PACK OF 12 WOODLAND TISSUES',
#   'PACK OF 12 RED RETROSPOT TISSUES',
#   'PACK OF 12 BLUE PAISLEY TISSUES',
#   'PACK OF 12 SKULL TISSUES',
#   '36 PENCILS TUBE WOODLAND',
#   '36 PENCILS TUBE SKULLS',
#   '36 PENCILS TUBE RED RETROSPOT',
#   'LIPSTICK PEN RED',
#   'CREAM HEART CARD HOLDER',
#   'SET3 BOOK BOX GREEN GINGHAM FLOWER',
#   'SET/3 RED GINGHAM ROSE STORAGE BOX',
#   'RED GINGHAM ROSE JEWELLERY BOX',
#   'WALL TIDY RETROSPOT',
#   'RED TOADSTOOL LED NIGHT LIGHT',
#   'PENS ASSORTED SPACEBALL',
#   'ASS FLORAL PRINT MULTI SCREWDRIVER',
#   'ASSTD DESIGN 3D PAPER STICKERS',
#   'ROSE DU SUD DRAWSTRING BAG',
#   'RED RETROSPOT MINI CASES',
#   'ASSORTED EASTER GIFT TAGS',
#   'FELTCRAFT 6 FLOWER FRIENDS',
#   'JAM MAKING SET PRINTED',
#   'SEWING BOX RETROSPOT DESIGN',
#   'DELUXE SEWING KIT',
#   'TRAVEL SEWING KIT',
#   'ROSE COTTAGE KEEPSAKE BOX',
#   'PAPER BUNTING WHITE LACE',
#   'PAPER BUNTING COLOURED LACE',
#   'PAPER BUNTING VINTAGE PAISLEY',
#   'PAPER BUNTING RETROSPOT',
#   'RED RETROSPOT ROUND CAKE TINS',
#   'CLOTHES PEGS RETROSPOT PACK 24',
#   'RED RETROSPOT PEG BAG',
#   'LUNCH BAG RED RETROSPOT',
#   'LUNCH BAG  BLACK SKULL.',
#   'ROUND CONTAINER SET OF 5 RETROSPOT',
#   'LUNCH BOX WITH CUTLERY RETROSPOT',
#   'PICNIC BOXES SET OF 3 RETROSPOT',
#   'MILK PAN RED RETROSPOT',
#   'RED RETROSPOT OVEN GLOVE DOUBLE',
#   'RED RETROSPOT OVEN GLOVE',
#   'SET 3 RETROSPOT TEA,COFFEE,SUGAR',
#   'RED RETROSPOT STORAGE JAR',
#   'SET/6 COLLAGE PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 FRUIT SALAD PAPER CUPS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'SET/6 COLLAGE PAPER PLATES',
#   'SET/6 RED SPOTTY PAPER PLATES',
#   'SET/6 FRUIT SALAD  PAPER PLATES',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'SET/20 RED RETROSPOT PAPER NAPKINS',
#   'PACK OF 20 SKULL PAPER NAPKINS',
#   'PICNIC BASKET WICKER SMALL',
#   'SET OF SALT AND PEPPER TOADSTOOLS',
#   'MINI CAKE STAND  HANGING STRAWBERY',
#   'BOX OF 24 COCKTAIL PARASOLS',
#   'CANDY SPOT EGG WARMER HARE',
#   'CANDY SPOT EGG WARMER RABBIT',
#   'FOOD CONTAINER SET 3 LOVE HEART',
#   'SMALL LICORICE DES PINK BOWL',
#   'SMALL CHOCOLATES PINK BOWL',
#   '12 RED ROSE PEG PLACE SETTINGS',
#   '12 IVORY ROSE PEG PLACE SETTINGS',
#   'PLACE SETTING WHITE HEART',
#   'HANGING PHOTO CLIP ROPE LADDER',
#   'MEMO BOARD COTTAGE DESIGN',
#   'MEMO BOARD RETROSPOT  DESIGN',
#   'TEA PARTY  WRAPPING PAPER',
#   'TOYBOX  WRAP',
#   'RED RETROSPOT WRAP',
#   'BLUE POLKADOT WRAP',
#   'PINK POLKADOT WRAP',
#   'PINK PAISLEY ROSE GIFT WRAP',
#   'BLUE SCANDINAVIAN PAISLEY WRAP',
#   'WRAP RED APPLES',
#   'WRAP MONSTER FUN',
#   'WRAP DOLLY GIRL',
#   'WRAP WEDDING DAY',
#   'WRAP CIRCUS PARADE',
#   'WRAP, BILLBOARD FONTS DESIGN',
#   'GINGHAM ROSE WRAP',
#   'SET 12 KIDS  WHITE CHALK STICKS',
#   'SET 12 KIDS COLOUR  CHALK STICKS',
#   'S/6 SEW ON CROCHET FLOWERS',
#   "POPPY'S PLAYHOUSE BEDROOM",
#   "POPPY'S PLAYHOUSE LIVINGROOM",
#   "POPPY'S PLAYHOUSE BATHROOM",
#   "POPPY'S PLAYHOUSE KITCHEN",
#   'BOHEMIAN COLLAGE STATIONERY SET',
#   'VINTAGE PAISLEY STATIONERY SET',
#   'MINI FUNKY DESIGN TAPES',
#   'RED RETROSPOT TAPE',
#   'SKULLS TAPE',
#   'STARS GIFT TAPE',
#   'CAKES AND BOWS GIFT  TAPE',
#   'FELT EGG COSY LADYBIRD',
#   'MAGNETS PACK OF 4 VINTAGE LABELS',
#   'MAGNETS PACK OF 4 RETRO PHOTO',
#   'TV DINNER TRAY AIR HOSTESS'],
#  ['SCOTTIES DESIGN WASHBAG',
#   'SAVE THE PLANET COTTON TOTE BAG',
#   'WOODLAND DESIGN  COTTON TOTE BAG',
#   'LOLITA  DESIGN  COTTON TOTE BAG',
#   'SILK PURSE BABUSHKA PINK',
#   'SILK PURSE BABUSHKA BLUE',
#   'SILK PURSE BABUSHKA RED',
#   'RED RETROSPOT MINI CASES',
#   'RED RETROSPOT UMBRELLA',
#   'CHARLOTTE BAG SUKI DESIGN',
#   'RED RETROSPOT CHARLOTTE BAG',
#   'WOODLAND CHARLOTTE BAG',
#   'FAWN BLUE HOT WATER BOTTLE',
#   'TRAVEL SEWING KIT',
#   'ROUND SNACK BOXES SET OF4 WOODLAND',
#   'ROUND SNACK BOXES SET OF 4 FRUITS',
#   'LUNCH BOX WITH CUTLERY RETROSPOT',
#   'SPACEBOY LUNCH BOX',
#   'BAKING MOULD CHOCOLATE CUPCAKES',
#   'BAKING SET 9 PIECE RETROSPOT',
#   'SET OF 6 SPICE TINS PANTRY DESIGN',
#   'SET OF 2 TEA TOWELS APPLE AND PEARS',
#   'SAVE THE PLANET MUG',
#   "IF YOU CAN'T STAND THE HEAT MUG",
#   "CHILDREN'S SPACEBOY MUG",
#   'COFFEE MUG APPLES DESIGN',
#   'PACK OF 20 NAPKINS PANTRY DESIGN',
#   'PACK OF 20 NAPKINS RED APPLES',
#   'SET/4 BADGES BALLOON GIRL',
#   'SET/4 BADGES DOGS',
#   'SET/4 BADGES CUTE CREATURES',
#   'MAGNETS PACK OF 4 RETRO PHOTO',
#   'MAGNETS PACK OF 4 SWALLOWS',
#   'SET OF 3 CAKE TINS PANTRY DESIGN',
#   'SET3 BOOK BOX GREEN GINGHAM FLOWER',
#   'SET OF 3 BUTTERFLY COOKIE CUTTERS',
#   'JUMBO STORAGE BAG SUKI',
#   'SUKI  SHOULDER BAG',
#   'DELUXE SEWING KIT',
#   '36 FOIL HEART CAKE CASES',
#   'RED GINGHAM ROSE JEWELLERY BOX'],
#  ['EASTER TIN KEEPSAKE',
#   'EASTER TIN CHICKS IN GARDEN',
#   'PACK OF 6 BIRDY GIFT TAGS',
#   'DOORMAT AIRMAIL'],
#  ['MINI FUNKY DESIGN TAPES',
#   'RED RETROSPOT TAPE',
#   'SKULLS TAPE',
#   'CAKES AND BOWS GIFT  TAPE',
#   'STARS GIFT TAPE',
#   'FELT FARM ANIMAL WHITE BUNNY',
#   'WALL TIDY RETROSPOT',
#   'BOTTLE BAG RETROSPOT',
#   'CABIN BAG VINTAGE RETROSPOT',
#   'LUNCH BAG WOODLAND',
#   'LUNCH BAG RED RETROSPOT',
#   'LUNCH BAG CARS BLUE',
#   'LUNCH BAG SUKI  DESIGN',
#   'BOX OF 24 COCKTAIL PARASOLS',
#   'CLOTHES PEGS RETROSPOT PACK 24'],
#  ['JAM MAKING SET PRINTED',
#   'TRAVEL SEWING KIT',
#   'SEWING SUSAN 21 NEEDLE SET',
#   'WOODEN PICTURE FRAME WHITE FINISH',
#   'VICTORIAN  METAL POSTCARD SPRING',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'CARD GINGHAM ROSE',
#   'WOODLAND PARTY BAG + STICKER SET'],
#  ['CREAM HEART CARD HOLDER',
#   'EDWARDIAN PARASOL PINK',
#   'METAL 4 HOOK HANGER FRENCH CHATEAU',
#   'BAKING SET 9 PIECE RETROSPOT',
#   'PACK OF 60 MUSHROOM CAKE CASES',
#   'CHOCOLATE BOX RIBBONS',
#   'WOODEN PICTURE FRAME WHITE FINISH',
#   'WOODEN FRAME ANTIQUE WHITE',
#   'RETROSPOT TEA SET CERAMIC 11 PC',
#   'SILVER HANGING T-LIGHT HOLDER'],
#  ['TV DINNER TRAY DOLLY GIRL',
#   'PENCIL CASE LIFE IS BEAUTIFUL',
#   'STRAWBERRY FAIRY CAKE TEAPOT',
#   'SET OF 3 NOTEBOOKS IN PARCEL',
#   'BAKING MOULD CHOCOLATE CUPCAKES',
#   'REGENCY CAKESTAND 3 TIER'],
#  ['ENAMEL COLANDER CREAM',
#   'FRYING PAN RED RETROSPOT',
#   'ROUND SNACK BOXES SET OF4 WOODLAND',
#   'ROUND SNACK BOXES SET OF 4 FRUITS',
#   'RED STRIPE CERAMIC DRAWER KNOB',
#   'RED SPOT CERAMIC DRAWER KNOB',
#   'RED RETROSPOT CUP',
#   'GREEN POLKADOT BOWL',
#   'SPACEBOY LUNCH BOX',
#   'WRAP ENGLISH ROSE',
#   'PACK OF 6 BIRDY GIFT TAGS',
#   'JAM JAR WITH PINK LID',
#   'RED RETROSPOT PLATE',
#   'RETROSPOT PARTY BAG + STICKER SET',
#   'GINGHAM ROSE WRAP',
#   'SET OF 16 VINTAGE SKY BLUE CUTLERY',
#   'SET OF 16 VINTAGE RED CUTLERY',
#   'SET OF 16 VINTAGE PISTACHIO CUTLERY'],
#  ['RED RETROSPOT PICNIC BAG'],
#  ['SPACE FROG',
#   'RED  HARMONICA IN BOX',
#   'ROUND SNACK BOXES SET OF4 WOODLAND',
#   'ROUND SNACK BOXES SET OF 4 FRUITS',
#   'CHILDS BREAKFAST SET CIRCUS PARADE',
#   'PINK BABY BUNTING',
#   'RED BABY BUNTING',
#   'SMALL RED RETROSPOT WINDMILL',
#   'WHITE WOOD GARDEN PLANT LADDER',
#   'RETROSPOT TEA SET CERAMIC 11 PC'],
#  ['ROUND SNACK BOXES SET OF 4 FRUITS',
#   'PICNIC BOXES SET OF 3 RETROSPOT',
#   'DOLLY GIRL LUNCH BOX',
#   'PHOTO CUBE',
#   '5 HOOK HANGER RED MAGIC TOADSTOOL',
#   'CHILDS BREAKFAST SET DOLLY GIRL',
#   'FAIRY CAKE BIRTHDAY CANDLE SET',
#   'HOMEMADE JAM SCENTED CANDLES',
#   'PIN CUSHION BABUSHKA BLUE',
#   'SEWING BOX RETROSPOT DESIGN',
#   'MEASURING TAPE BABUSHKA BLUE',
#   'JAM MAKING SET WITH JARS',
#   'CHILDRENS APRON SPACEBOY DESIGN',
#   'SET/6 FRUIT SALAD PAPER CUPS',
#   'SET/6 FRUIT SALAD  PAPER PLATES',
#   'TABLECLOTH RED APPLES DESIGN',
#   'PLASTERS IN TIN SPACEBOY',
#   'WALL TIDY RETROSPOT',
#   "NURSE'S BAG SOFT TOY",
#   'TOOL BOX SOFT TOY',
#   'MR ROBOT SOFT TOY',
#   'MRS ROBOT SOFT TOY',
#   'BLUE OWL SOFT TOY',
#   'TRADITIONAL WOODEN SKIPPING ROPE',
#   'S/6 WOODEN SKITTLES IN COTTON BAG',
#   'WOODEN BOX OF DOMINOES',
#   'GINGHAM BABUSHKA DOORSTOP',
#   '3 PIECE SPACEBOY COOKIE CUTTER SET',
#   'BAKING SET SPACEBOY DESIGN',
#   'CABIN BAG VINTAGE RETROSPOT',
#   'SILK PURSE BABUSHKA PINK',
#   'RED RETROSPOT PURSE',
#   'SILK PURSE BABUSHKA BLUE',
#   'FAWN BLUE HOT WATER BOTTLE',
#   'RETROSPOT BABUSHKA DOORSTOP',
#   'CHILDRENS APRON APPLES DESIGN',
#   'COFFEE MUG APPLES DESIGN',
#   'PACK OF 20 NAPKINS RED APPLES',
#   'ROUND SNACK BOXES SET OF4 WOODLAND',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'WOODLAND  HEIGHT CHART STICKERS',
#   'SET/20 RED RETROSPOT PAPER NAPKINS',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES',
#   'RETROSPOT CHILDRENS APRON',
#   'RETROSPOT LAMP',
#   'RETROSPOT TEA SET CERAMIC 11 PC',
#   'ROUND CONTAINER SET OF 5 RETROSPOT',
#   'LUNCH BOX WITH CUTLERY RETROSPOT',
#   'BIRD DECORATION RED RETROSPOT',
#   'BAKING SET 9 PIECE RETROSPOT',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY'],
#  ['INFLATABLE POLITICAL GLOBE',
#   'BAKING MOULD HEART WHITE CHOCOLATE',
#   'EIGHT PIECE DINOSAUR SET',
#   'RECYCLED PENCIL WITH RABBIT ERASER',
#   '12 PENCILS SMALL TUBE RED RETROSPOT',
#   '12 PENCILS SMALL TUBE SKULL',
#   'FEATHER PEN,HOT PINK',
#   'FEATHER PEN,LIGHT PINK',
#   'BLUE PARTY BAGS',
#   'PINK PARTY BAGS',
#   'MONSTERS STENCIL CRAFT',
#   'HAPPY STENCIL CRAFT',
#   'BLUE HAPPY BIRTHDAY BUNTING',
#   'PINK HAPPY BIRTHDAY BUNTING',
#   'CHILDS GARDEN RAKE BLUE',
#   'SET OF 6 SOLDIER SKITTLES',
#   'PARTY CONES CANDY ASSORTED',
#   '4 TRADITIONAL SPINNING TOPS',
#   '3 PIECE SPACEBOY COOKIE CUTTER SET',
#   'SMALL POPCORN HOLDER',
#   'DOORMAT UNION JACK GUNS AND ROSES',
#   'DOORMAT WELCOME TO OUR HOME',
#   'DOORMAT WELCOME PUPPIES'],
#  ['WOODLAND  HEIGHT CHART STICKERS',
#   'DINOSAUR HEIGHT CHART STICKER SET',
#   'CHARLOTTE BAG PINK POLKADOT',
#   'CHARLOTTE BAG DOLLY GIRL DESIGN',
#   'RED RETROSPOT CHARLOTTE BAG',
#   'WOODLAND CHARLOTTE BAG',
#   'SET/10 RED POLKADOT PARTY CANDLES',
#   'FUNKY MONKEY GIFT BAG MEDIUM',
#   'FAWN AND MUSHROOM GREETING CARD'],
#  ['STRAWBERRY CERAMIC TRINKET BOX', 'SWEETHEART CERAMIC TRINKET BOX'],
#  ['OVEN MITT APPLES DESIGN',
#   'SET OF 3 CAKE TINS SKETCHBOOK',
#   'PEG BAG APPLES DESIGN',
#   'SET OF 6 HERB TINS SKETCHBOOK',
#   'SET OF 2 TEA TOWELS APPLE AND PEARS',
#   'SET 2 TEA TOWELS I LOVE LONDON',
#   'REGENCY CAKESTAND 3 TIER',
#   'BOX OF 24 COCKTAIL PARASOLS',
#   'CHILDS BREAKFAST SET CIRCUS PARADE',
#   'COFFEE MUG PEARS  DESIGN',
#   'COFFEE MUG APPLES DESIGN',
#   "CHILDREN'S CIRCUS PARADE MUG",
#   'PACK OF 20 NAPKINS RED APPLES',
#   'PACK OF 12 WOODLAND TISSUES',
#   'WOODLAND  STICKERS',
#   'WRAP RED APPLES',
#   'EMERGENCY FIRST AID TIN',
#   'HAND WARMER BABUSHKA DESIGN',
#   'RIDGED GLASS POSY VASE'],
#  ['SET 3 PAPER VINTAGE CHICK PAPER EGG',
#   'SET 3 SONG BIRD PAPER EGGS ASSORTED',
#   'BAKING MOULD CHOCOLATE CUPCAKES',
#   'MINT KITCHEN SCALES',
#   'RED RETROSPOT UMBRELLA',
#   'PENCIL CASE LIFE IS BEAUTIFUL',
#   'MILK PAN PINK POLKADOT',
#   'RED RETROSPOT TAPE'],
#  ['RETROSPOT LAMP',
#   'GLITTER BUTTERFLY CLIPS',
#   'RAIN PONCHO RETROSPOT',
#   'WRAP RED APPLES',
#   'WRAP WEDDING DAY',
#   'TEA PARTY  WRAPPING PAPER',
#   'WRAP CIRCUS PARADE',
#   'WRAP I LOVE LONDON',
#   'WRAP COWBOYS',
#   'RAINY LADIES BIRTHDAY CARD',
#   'ROBOT BIRTHDAY CARD',
#   'RING OF ROSES BIRTHDAY CARD',
#   'ELEPHANT, BIRTHDAY CARD,',
#   'VINTAGE KID DOLLY CARD',
#   'COWBOYS AND INDIANS BIRTHDAY CARD',
#   'CARD PARTY GAMES',
#   'PACK 3 BOXES BIRD PANNETONE',
#   'MAKE YOUR OWN PLAYTIME CARD KIT',
#   'MAKE YOUR OWN MONSOON CARD KIT',
#   'CALENDAR FAMILY FAVOURITES',
#   'WOODLAND  HEIGHT CHART STICKERS',
#   'DINOSAUR HEIGHT CHART STICKER SET',
#   'MAGIC DRAWING SLATE SPACEBOY',
#   'MAGIC DRAWING SLATE BUNNIES',
#   'MAGIC DRAWING SLATE DINOSAUR',
#   'PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'PLASTERS IN TIN STRONGMAN',
#   'PLASTERS IN TIN CIRCUS PARADE',
#   'SET 10 LIGHTS NIGHT OWL',
#   "CHILDREN'S APRON DOLLY GIRL",
#   'CHILDRENS APRON SPACEBOY DESIGN',
#   'CAKE STAND 3 TIER MAGIC GARDEN',
#   '5 HOOK HANGER MAGIC TOADSTOOL',
#   '10 COLOUR SPACEBOY PEN',
#   'WATERING CAN PINK BUNNY',
#   'BLUE HAPPY BIRTHDAY BUNTING',
#   'PARTY BUNTING',
#   'SET/10 RED POLKADOT PARTY CANDLES',
#   'SET/10 PINK POLKADOT PARTY CANDLES',
#   'SET/10 BLUE POLKADOT PARTY CANDLES',
#   'PAPER BUNTING WHITE LACE',
#   'PAPER BUNTING COLOURED LACE',
#   'SET 3 PAPER VINTAGE CHICK PAPER EGG',
#   'ASSORTED EASTER GIFT TAGS',
#   'OFFICE MUG WARMER BLACK+SILVER',
#   'REGENCY CAKESTAND 3 TIER',
#   'JAM MAKING SET PRINTED',
#   'JAM JAR WITH PINK LID',
#   'JAM JAR WITH GREEN LID',
#   'RECIPE BOX PANTRY YELLOW DESIGN',
#   'JUNGLE POPSICLES ICE LOLLY HOLDERS'],
#  ['RED 3 PIECE RETROSPOT CUTLERY SET',
#   'SET OF 6 GIRLS CELEBRATION CANDLES',
#   'SET/10 PINK POLKADOT PARTY CANDLES',
#   'FUNKY DIVA PEN',
#   'POLKADOT PEN',
#   'RETROSPOT PARTY BAG + STICKER SET',
#   'SET/20 RED RETROSPOT PAPER NAPKINS',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES',
#   'RED RETROSPOT CHILDRENS UMBRELLA',
#   'JAM MAKING SET WITH JARS',
#   'BLUE POLKADOT BOWL',
#   'BLUE POLKADOT CUP',
#   'RED RETROSPOT PLATE',
#   'SET/3 RED GINGHAM ROSE STORAGE BOX',
#   'RED RETROSPOT BOWL',
#   'RED RETROSPOT CUP',
#   'RETROSPOT CHILDRENS APRON',
#   'WATERING CAN GREEN DINOSAUR',
#   'WATERING CAN PINK BUNNY',
#   '5 HOOK HANGER MAGIC TOADSTOOL',
#   '5 HOOK HANGER RED MAGIC TOADSTOOL',
#   'RED TOADSTOOL LED NIGHT LIGHT',
#   'FAIRY TALE COTTAGE NIGHTLIGHT',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY',
#   'DINOSAUR LUNCH BOX WITH CUTLERY',
#   'PINK 3 PIECE POLKADOT CUTLERY SET',
#   'ASSORTED EASTER GIFT TAGS',
#   'PACK OF 6 BIRDY GIFT TAGS',
#   'SET 3 PAPER VINTAGE CHICK PAPER EGG',
#   'SET 3 SONG BIRD PAPER EGGS ASSORTED',
#   'GREEN DRAWER KNOB ACRYLIC EDWARDIAN',
#   'CLEAR DRAWER KNOB ACRYLIC EDWARDIAN',
#   'WHITE SPOT BLUE CERAMIC DRAWER KNOB',
#   'BLUE SPOT CERAMIC DRAWER KNOB',
#   'SET OF 3 CAKE TINS PANTRY DESIGN',
#   'SET/10 RED POLKADOT PARTY CANDLES',
#   'WOODLAND CHARLOTTE BAG',
#   'JUMBO BAG OWLS',
#   'RECIPE BOX PANTRY YELLOW DESIGN',
#   'JUMBO SHOPPER VINTAGE RED PAISLEY',
#   'JUMBO BAG PINK POLKADOT',
#   'JUMBO BAG PINK VINTAGE PAISLEY',
#   'JUMBO BAG RED RETROSPOT',
#   'JUMBO BAG SCANDINAVIAN PAISLEY',
#   'JUMBO BAG WOODLAND ANIMALS',
#   'FAWN AND MUSHROOM GREETING CARD',
#   'BASKET OF TOADSTOOLS',
#   'CHARLOTTE BAG SUKI DESIGN',
#   'PINK POLKADOT CHILDRENS UMBRELLA',
#   'WOODLAND DESIGN  COTTON TOTE BAG',
#   'SET 6 FOOTBALL CELEBRATION CANDLES'],
#  ['SET OF 72 RETROSPOT PAPER  DOILIES',
#   'REGENCY CAKESTAND 3 TIER',
#   'SET 12 RETRO WHITE CHALK STICKS',
#   'RETROSPOT CIGAR BOX MATCHES',
#   'MINT KITCHEN SCALES',
#   'RED RETROSPOT BOWL',
#   'RED RETROSPOT CUP',
#   'RED RETROSPOT ROUND CAKE TINS',
#   'SET 3 RETROSPOT TEA,COFFEE,SUGAR',
#   'GLASS  BEURRE DISH'],
#  ['KIDS RAIN MAC BLUE',
#   'KIDS RAIN MAC PINK',
#   'SET OF SALT AND PEPPER TOADSTOOLS',
#   'MEMO BOARD COTTAGE DESIGN',
#   'RED RETROSPOT APRON',
#   "CHILDREN'S APRON DOLLY GIRL",
#   'LONDON BUS COFFEE MUG',
#   'SPACEBOY LUNCH BOX',
#   'DOLLY GIRL LUNCH BOX',
#   'PACK OF 12 SPACEBOY TISSUES',
#   'PACK OF 12 LONDON TISSUES',
#   'PACK OF 12 WOODLAND TISSUES',
#   'MR ROBOT SOFT TOY',
#   'WALL TIDY RETROSPOT',
#   'QUEENS GUARD COFFEE MUG'],
#  ['RED RETROSPOT CUP',
#   'REGENCY CAKESTAND 3 TIER',
#   'PIN CUSHION BABUSHKA RED',
#   'PIN CUSHION BABUSHKA BLUE',
#   'PIN CUSHION BABUSHKA PINK',
#   '6 RIBBONS RUSTIC CHARM',
#   'CHOCOLATE BOX RIBBONS',
#   'ORGANISER WOOD ANTIQUE WHITE',
#   'SET 10 LIGHTS NIGHT OWL',
#   'WHITE SPOT BLUE CERAMIC DRAWER KNOB',
#   'RED STRIPE CERAMIC DRAWER KNOB',
#   'BLUE SPOT CERAMIC DRAWER KNOB',
#   'RED SPOT CERAMIC DRAWER KNOB',
#   'WHITE SPOT RED CERAMIC DRAWER KNOB',
#   'CARD CIRCUS PARADE',
#   'CARD CAT AND TREE',
#   'CARD PSYCHEDELIC APPLES',
#   'CARD SUKI BIRTHDAY',
#   'SCANDINAVIAN REDS RIBBONS',
#   'BABY BOOM RIBBONS',
#   'ROMANTIC PINKS RIBBONS',
#   'BRIGHT BLUES RIBBONS',
#   'URBAN BLACK RIBBONS',
#   'GREEN POLKADOT BOWL',
#   'BLUE POLKADOT BOWL',
#   'PINK  POLKADOT CUP',
#   'BLUE POLKADOT CUP',
#   'RED RETROSPOT PLATE',
#   'BLUE POLKADOT PLATE',
#   'GREEN POLKADOT PLATE',
#   'BLUE HARMONICA IN BOX',
#   'RED  HARMONICA IN BOX',
#   'RED RETROSPOT BOWL',
#   'ROUND SNACK BOXES SET OF4 WOODLAND',
#   'FAWN AND MUSHROOM GREETING CARD',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'SPACEBOY LUNCH BOX',
#   'ROUND SNACK BOXES SET OF 4 FRUITS',
#   '5 HOOK HANGER MAGIC TOADSTOOL',
#   'HOOK, 1 HANGER ,MAGIC GARDEN',
#   'GUMBALL COAT RACK'],
#  ['PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN CIRCUS PARADE',
#   'WOODLAND PARTY BAG + STICKER SET',
#   'SKULLS PARTY BAG + STICKER SET',
#   'DINOSAUR PARTY BAG + STICKER SET',
#   'RETROSPOT PARTY BAG + STICKER SET',
#   'FELTCRAFT DOLL ROSIE',
#   'PINK HORSE SOCK PUPPET',
#   'MINI WOODEN HAPPY BIRTHDAY GARLAND',
#   'PAPER BUNTING RETROSPOT',
#   'LARGE HANGING IVORY & RED WOOD BIRD',
#   'SMALL HANGING IVORY/RED WOOD BIRD',
#   'GUMBALL COAT RACK',
#   'FOUR HOOK  WHITE LOVEBIRDS',
#   'DOLLY HONEYCOMB GARLAND',
#   'SPACEBOY BIRTHDAY CARD',
#   'SET/20 RED RETROSPOT PAPER NAPKINS',
#   'PACK OF 20 SKULL PAPER NAPKINS',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY',
#   'RED 3 PIECE RETROSPOT CUTLERY SET',
#   'BLUE 3 PIECE POLKADOT CUTLERY SET'],
#  ['5 HOOK HANGER RED MAGIC TOADSTOOL',
#   'FELT TOADSTOOL  SMALL',
#   'FELT FARM ANIMAL WHITE BUNNY',
#   'FELT TOADSTOOL LARGE',
#   'BASKET OF TOADSTOOLS',
#   'RABBIT  DESIGN  COTTON TOTE BAG',
#   '3 HOOK HANGER MAGIC GARDEN',
#   'DOLLY GIRL LUNCH BOX',
#   'CIRCUS PARADE LUNCH BOX',
#   'ROUND SNACK BOXES SET OF 4 FRUITS',
#   'MINI PAINT SET VINTAGE',
#   'PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN STRONGMAN',
#   'PLASTERS IN TIN CIRCUS PARADE',
#   'PLASTERS IN TIN VINTAGE PAISLEY'],
#  ['SET 3 PAPER VINTAGE CHICK PAPER EGG',
#   'RED RETROSPOT TAPE',
#   'STARS GIFT TAPE',
#   'CABIN BAG VINTAGE RETROSPOT',
#   'CHILDRENS APRON APPLES DESIGN',
#   'PACK OF 60 MUSHROOM CAKE CASES',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'PLASTERS IN TIN CIRCUS PARADE',
#   'SOMBRERO',
#   'CARD CIRCUS PARADE',
#   'BIG DOUGHNUT FRIDGE MAGNETS'],
#  ['RED TOADSTOOL LED NIGHT LIGHT',
#   'CHILDRENS APRON SPACEBOY DESIGN',
#   'CHILDS BREAKFAST SET SPACEBOY',
#   'COFFEE MUG PEARS  DESIGN',
#   'SPACEBOY LUNCH BOX'],
#  ['RED RETROSPOT CAKE STAND',
#   'REGENCY CAKESTAND 3 TIER',
#   'CERAMIC CAKE DESIGN SPOTTED PLATE',
#   'FAIRY CAKE BIRTHDAY CANDLE SET',
#   'TEA TIME KITCHEN APRON',
#   'TEA TIME TABLE CLOTH',
#   'TEA TIME DES TEA COSY',
#   'SET OF 36 TEATIME PAPER DOILIES',
#   'TEA TIME TEAPOT IN GIFT BOX',
#   'TEA TIME TEA SET IN GIFT BOX',
#   'TEA TIME OVEN GLOVE',
#   'PINK FAIRY CAKE CUSHION COVER',
#   'PINK PARTY BAGS',
#   'BLUE PARTY BAGS',
#   'SET OF 4 FAIRY CAKE PLACEMATS',
#   'FAIRY CAKES NOTEBOOK A6 SIZE',
#   'FAIRY CAKES NOTEBOOK A7 SIZE',
#   'CERAMIC CAKE DESIGN SPOTTED MUG',
#   'SET 20 NAPKINS FAIRY CAKES DESIGN',
#   'CAKES AND BOWS GIFT  TAPE',
#   'FAIRY CAKE DESIGN UMBRELLA',
#   'WRAP PINK FAIRY CAKES',
#   'PACK OF 72 RETROSPOT CAKE CASES',
#   'PACK OF 72 SKULL CAKE CASES',
#   'STRAWBERRY CERAMIC TRINKET BOX',
#   'CAKE STAND WHITE TWO TIER LACE',
#   'MINI CAKE STAND WITH HANGING CAKES',
#   'CERAMIC CAKE BOWL + HANGING CAKES',
#   '60 TEATIME FAIRY CAKE CASES',
#   'TEA TIME PARTY BUNTING'],
#  ['GREEN POLKADOT PLATE',
#   'BLUE POLKADOT PLATE',
#   'BLUE POLKADOT CUP',
#   'LUNCH BAG PINK POLKADOT',
#   'LUNCH BAG RED RETROSPOT',
#   'LUNCH BAG WOODLAND',
#   'RED RETROSPOT PICNIC BAG',
#   'STRAWBERRY   PICNIC BAG',
#   'RED RETROSPOT MUG',
#   'MEMO BOARD COTTAGE DESIGN',
#   'PACK OF 12 RED RETROSPOT TISSUES',
#   'POTTING SHED SEED ENVELOPES',
#   'GREEN POLKADOT BOWL',
#   'SET/20 RED RETROSPOT PAPER NAPKINS',
#   'PACK OF 72 RETROSPOT CAKE CASES',
#   'STRAWBERRY SHOPPER BAG',
#   'PARTY FOOD SHOPPER BAG',
#   'POTTING SHED TWINE'],
#  ['BREAD BIN DINER STYLE IVORY',
#   'BREAD BIN DINER STYLE MINT',
#   'SET OF 3 CAKE TINS PANTRY DESIGN',
#   'ENAMEL FLOWER JUG CREAM',
#   'MINT KITCHEN SCALES',
#   'ROUND SNACK BOXES SET OF 4 FRUITS',
#   'BLUE POLKADOT WASHING UP GLOVES',
#   'IVORY KITCHEN SCALES',
#   'CHICK GREY HOT WATER BOTTLE',
#   'WOODEN CROQUET GARDEN SET',
#   'ZINC WILLIE WINKIE  CANDLE STICK',
#   '6 RIBBONS RUSTIC CHARM',
#   'WOOD BLACK BOARD ANT WHITE FINISH',
#   'OWL DOORSTOP',
#   'VICTORIAN  METAL POSTCARD SPRING',
#   'ASSORTED COLOUR BIRD ORNAMENT',
#   'GUMBALL COAT RACK',
#   'BLACK RECORD COVER FRAME',
#   'REGENCY CAKESTAND 3 TIER',
#   'CHERRY BLOSSOM  DECORATIVE FLASK'],
#  ['PLASTERS IN TIN SPACEBOY',
#   'LIPSTICK PEN RED',
#   'SET OF 9 HEART SHAPED BALLOONS',
#   'BIG DOUGHNUT FRIDGE MAGNETS',
#   'TOADSTOOL MONEY BOX',
#   'CERAMIC STRAWBERRY MONEY BOX',
#   'CERAMIC STRAWBERRY CAKE MONEY BANK',
#   'WOODLAND DESIGN  COTTON TOTE BAG',
#   'SILK PURSE BABUSHKA PINK',
#   'RED RETROSPOT PURSE',
#   'POLKADOT RAIN HAT',
#   'APPLE BATH SPONGE',
#   'WHITE SKULL HOT WATER BOTTLE',
#   'FAIRY CAKE BIRTHDAY CANDLE SET',
#   'SET OF 6 T-LIGHTS TOADSTOOLS',
#   '5 HOOK HANGER RED MAGIC TOADSTOOL',
#   'FOUR HOOK  WHITE LOVEBIRDS',
#   'BLACK RECORD COVER FRAME',
#   'BAKING SET 9 PIECE RETROSPOT',
#   'RED SPOTTY BISCUIT TIN',
#   'SET OF 3 CAKE TINS PANTRY DESIGN',
#   'PACK OF 72 SKULL CAKE CASES',
#   '60 TEATIME FAIRY CAKE CASES',
#   'SET OF 6 SPICE TINS PANTRY DESIGN',
#   'MILK PAN PINK POLKADOT',
#   'MILK PAN BLUE POLKADOT',
#   'RED RETROSPOT STORAGE JAR',
#   'SET OF SALT AND PEPPER TOADSTOOLS',
#   'SWEETHEART CERAMIC TRINKET BOX',
#   'STRAWBERRY CERAMIC TRINKET BOX',
#   'PINK DOUGHNUT TRINKET POT',
#   'CHOC TRUFFLE GOLD TRINKET POT',
#   'CERAMIC BOWL WITH STRAWBERRY DESIGN',
#   'CERAMIC CAKE BOWL + HANGING CAKES',
#   'MINI LADLE LOVE HEART RED',
#   'SET OF 72 RETROSPOT PAPER  DOILIES',
#   'CHILDS BREAKFAST SET SPACEBOY',
#   'CHILDS BREAKFAST SET DOLLY GIRL',
#   'COFFEE MUG APPLES DESIGN',
#   'CERAMIC STRAWBERRY DESIGN MUG',
#   'CERAMIC CAKE DESIGN SPOTTED MUG',
#   'RED RETROSPOT TEA CUP AND SAUCER',
#   "CHILDREN'S SPACEBOY MUG",
#   'VINTAGE BILLBOARD LOVE/HATE MUG',
#   'SET OF 4 FAIRY CAKE PLACEMATS',
#   'CERAMIC CAKE DESIGN SPOTTED PLATE',
#   'TABLECLOTH RED APPLES DESIGN',
#   'STRAWBERRY FAIRY CAKE TEAPOT',
#   'TEA TIME TEAPOT IN GIFT BOX'],
#  ['PINK PADDED MOBILE',
#   'METAL 4 HOOK HANGER FRENCH CHATEAU',
#   'BIRDS MOBILE VINTAGE DESIGN',
#   '3 HOOK PHOTO SHELF ANTIQUE WHITE',
#   'ORGANISER WOOD ANTIQUE WHITE',
#   'WOODEN FRAME ANTIQUE WHITE',
#   'KEY CABINET MA CAMPAGNE',
#   'SET 3 PAPER VINTAGE CHICK PAPER EGG',
#   'BROCANTE COAT RACK',
#   'BLUE COAT RACK PARIS FASHION'],
#  ["CHILDREN'S APRON DOLLY GIRL"],
#  ['ENGLISH ROSE NOTEBOOK A7 SIZE',
#   'ASSORTED COLOUR BIRD ORNAMENT',
#   'SPACEBOY TV DINNER TRAY',
#   'TV DINNER TRAY AIR HOSTESS',
#   'VICTORIAN GLASS HANGING T-LIGHT',
#   'EDWARDIAN PARASOL RED',
#   'RED RETROSPOT UMBRELLA'],
#  ['SET OF 72 PINK HEART PAPER DOILIES',
#   'STRAWBERRY CERAMIC TRINKET BOX',
#   'SWEETHEART CERAMIC TRINKET BOX',
#   '6 RIBBONS RUSTIC CHARM',
#   'TV DINNER TRAY DOLLY GIRL',
#   'PENCIL CASE LIFE IS BEAUTIFUL',
#   'STRAWBERRY FAIRY CAKE TEAPOT',
#   'SET 7 BABUSHKA NESTING BOXES',
#   'MAKE YOUR OWN MONSOON CARD KIT',
#   'MAKE YOUR OWN FLOWERPOWER CARD KIT',
#   'ALARM CLOCK BAKELIKE PINK',
#   'ROSE COTTAGE KEEPSAKE BOX',
#   'REGENCY CAKESTAND 3 TIER',
#   'SET OF 3 CAKE TINS PANTRY DESIGN',
#   'RED COAT RACK PARIS FASHION'],
#  ['RED RETROSPOT MINI CASES',
#   'ROUND SNACK BOXES SET OF4 WOODLAND',
#   'PAPER BUNTING RETROSPOT',
#   'BLUE OWL SOFT TOY',
#   'HAIRCLIPS FORTIES FABRIC ASSORTED',
#   'BLUE HARMONICA IN BOX',
#   'FAWN BLUE HOT WATER BOTTLE',
#   'TRADITIONAL WOODEN CATCH CUP GAME',
#   "POPPY'S PLAYHOUSE BEDROOM",
#   'TINY CRYSTAL BRACELET GREEN',
#   'NECKLACE+BRACELET PINK BUTTERFLY',
#   'ROUND SNACK BOXES SET OF 4 FRUITS',
#   'CIRCUS PARADE CHILDRENS EGG CUP',
#   'WRAP CIRCUS PARADE',
#   'TOYBOX  WRAP',
#   'JIGSAW TREE WITH BIRDHOUSE',
#   'WOODLAND CHARLOTTE BAG',
#   'MEMO BOARD COTTAGE DESIGN'],
#  ['WRAP DOILEY DESIGN',
#   'SET 2 PANTRY DESIGN TEA TOWELS',
#   'SMALL POPCORN HOLDER',
#   'BASKET OF TOADSTOOLS',
#   'EASTER TIN KEEPSAKE',
#   'EASTER TIN BUNNY BOUQUET',
#   'EASTER TIN CHICKS PINK DAISY',
#   'BOTANICAL ROSE GIFT WRAP',
#   'GINGHAM ROSE WRAP',
#   'UNION STRIPE CUSHION COVER',
#   'RED/CREAM STRIPE CUSHION COVER',
#   'BLUE/CREAM STRIPE CUSHION COVER'],
#  ['WOODEN FRAME ANTIQUE WHITE',
#   'SMALL GLASS HEART TRINKET POT',
#   '20 DOLLY PEGS RETROSPOT',
#   'VINTAGE NOTEBOOK PARIS DAYS',
#   'ZINC WILLIE WINKIE  CANDLE STICK'],
#  ['FOUR HOOK  WHITE LOVEBIRDS',
#   'SET/20 RED RETROSPOT PAPER NAPKINS',
#   'RED RETROSPOT WRAP',
#   'BLUE POLKADOT WRAP',
#   'PINK POLKADOT WRAP',
#   'WRAP RED APPLES',
#   'SET/3 POLKADOT STACKING TINS',
#   'SET/2 RED RETROSPOT TEA TOWELS',
#   'PHARMACIE FIRST AID TIN',
#   'METAL 4 HOOK HANGER FRENCH CHATEAU',
#   'DOORMAT WELCOME TO OUR HOME',
#   'DOORMAT ENGLISH ROSE',
#   'ROUND SNACK BOXES SET OF4 WOODLAND',
#   'CIRCUS PARADE LUNCH BOX',
#   'SET 2 PANTRY DESIGN TEA TOWELS',
#   'PACK OF 20 NAPKINS PANTRY DESIGN'],
#  ['CHICK GREY HOT WATER BOTTLE',
#   'BLUE BIRDHOUSE DECORATION',
#   'DOORMAT FANCY FONT HOME SWEET HOME',
#   'DOORMAT RESPECTABLE HOUSE',
#   'DOORMAT AIRMAIL',
#   'DOORMAT NEIGHBOURHOOD WITCH',
#   'DOORMAT HOME SWEET HOME BLUE',
#   'DOORMAT NEW ENGLAND',
#   'WATERING CAN BLUE ELEPHANT',
#   'RETROSPOT PADDED SEAT CUSHION',
#   'WHITE SPOT RED CERAMIC DRAWER KNOB',
#   'BLUE DRAWER KNOB ACRYLIC EDWARDIAN',
#   'RETROSPOT BABUSHKA DOORSTOP',
#   'OWL DOORSTOP',
#   'DOORSTOP RETROSPOT HEART',
#   'GINGHAM HEART  DOORSTOP RED',
#   'BLUE  TILE HOOK',
#   'FOUR HOOK  WHITE LOVEBIRDS',
#   '5 HOOK HANGER RED MAGIC TOADSTOOL',
#   '3 HOOK HANGER MAGIC GARDEN',
#   'YELLOW COAT RACK PARIS FASHION',
#   'CREAM CUPID HEARTS COAT HANGER',
#   'RED SPOTTY BISCUIT TIN',
#   'ENAMEL BLUE RIM BISCUIT BIN',
#   'RED RETROSPOT ROUND CAKE TINS',
#   'SET OF 3 CAKE TINS PANTRY DESIGN',
#   'SET OF 3 CAKE TINS SKETCHBOOK',
#   'FRYING PAN RED RETROSPOT',
#   'SET OF 6 HERB TINS SKETCHBOOK',
#   'SET OF 6 SPICE TINS PANTRY DESIGN',
#   'PEG BAG APPLES DESIGN',
#   'MILK PAN RED RETROSPOT',
#   'OVEN MITT APPLES DESIGN',
#   'SET 3 RETROSPOT TEA,COFFEE,SUGAR',
#   'ENAMEL BLUE RIM COFFEE CONTAINER',
#   'BLUE TEA TOWEL CLASSIC DESIGN',
#   'SET 2 TEA TOWELS I LOVE LONDON',
#   'SET OF 16 VINTAGE ROSE CUTLERY',
#   'SET OF 16 VINTAGE RED CUTLERY',
#   'SET OF 16 VINTAGE SKY BLUE CUTLERY',
#   'RED 3 PIECE RETROSPOT CUTLERY SET',
#   'FELT EGG COSY BLUE RABBIT',
#   'FELT EGG COSY CHICKEN',
#   'PINK  HEART SHAPE LOVE BUCKET',
#   'RED HEART SHAPE LOVE BUCKET',
#   'RETROSPOT HEART HOT WATER BOTTLE',
#   'SUKI  SHOULDER BAG',
#   'SILK PURSE BABUSHKA PINK',
#   'FOLDING UMBRELLA RED/WHITE POLKADOT',
#   'ORGANISER WOOD ANTIQUE WHITE',
#   'RED STRIPE CERAMIC DRAWER KNOB',
#   'BLUE STRIPE CERAMIC DRAWER KNOB'],
#  ['BROCANTE COAT RACK',
#   'SET 3 PAPER VINTAGE CHICK PAPER EGG',
#   'VINTAGE UNION JACK BUNTING',
#   'SET OF 6 SPICE TINS PANTRY DESIGN',
#   'LUNCH BAG PINK POLKADOT',
#   'VINTAGE HEADS AND TAILS CARD GAME',
#   'BOYS VINTAGE TIN SEASIDE BUCKET'],
#  ['CHARLOTTE BAG SUKI DESIGN',
#   'WOODLAND CHARLOTTE BAG',
#   'STRAWBERRY CHARLOTTE BAG',
#   'BROCADE RING PURSE',
#   'WOODLAND PARTY BAG + STICKER SET',
#   'JUMBO BAG SPACEBOY DESIGN',
#   'PACK 3 FIRE ENGINE/CAR PATCHES',
#   'RED  HARMONICA IN BOX',
#   'TRADITIONAL MODELLING CLAY',
#   'BLUE HARMONICA IN BOX',
#   'SET 3 PAPER VINTAGE CHICK PAPER EGG',
#   '6 RIBBONS RUSTIC CHARM',
#   'STRAWBERRY   PICNIC BAG',
#   'WRAP CIRCUS PARADE',
#   'DOLLY GIRL LUNCH BOX',
#   'LUNCH BAG WOODLAND',
#   'LUNCH BAG CARS BLUE',
#   'ROUND SNACK BOXES SET OF4 WOODLAND',
#   'LUNCH BAG SUKI  DESIGN',
#   'LUNCH BAG DOLLY GIRL DESIGN',
#   'PACK 3 BOXES BIRD PANNETONE',
#   'ALARM CLOCK BAKELIKE ORANGE',
#   'ALARM CLOCK BAKELIKE RED',
#   'ALARM CLOCK BAKELIKE CHOCOLATE',
#   'EASTER TIN CHICKS PINK DAISY',
#   'ASSORTED EASTER GIFT TAGS',
#   'CHARLOTTE BAG DOLLY GIRL DESIGN',
#   'WRAP POPPIES  DESIGN',
#   'GINGERBREAD MAN COOKIE CUTTER'],
#  ['PACK OF 6 BIRDY GIFT TAGS',
#   'DOORMAT AIRMAIL',
#   'BAKING MOULD HEART WHITE CHOCOLATE',
#   'BAKING MOULD ROSE WHITE CHOCOLATE'],
#  ['WOODLAND CHARLOTTE BAG',
#   'ROUND SNACK BOXES SET OF4 WOODLAND',
#   'WOODLAND DESIGN  COTTON TOTE BAG',
#   'SPACEBOY LUNCH BOX',
#   'WATERING CAN GREEN DINOSAUR',
#   'WATERING CAN BLUE ELEPHANT',
#   'WATERING CAN PINK BUNNY',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY',
#   'SKULL LUNCH BOX WITH CUTLERY',
#   'RED TOADSTOOL LED NIGHT LIGHT'],
#  ['SET/6 TURQUOISE BUTTERFLY T-LIGHTS',
#   'SET/6 PINK  BUTTERFLY T-LIGHTS',
#   'SET/6 EAU DE NIL BIRD T-LIGHTS',
#   'PACK OF 60 PINK PAISLEY CAKE CASES',
#   '60 TEATIME FAIRY CAKE CASES'],
#  ['SET OF 4 PANTRY JELLY MOULDS',
#   'SET/6 FRUIT SALAD PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'BLUE SAVANNAH PICNIC HAMPER FOR 2',
#   'CIRCUS PARADE LUNCH BOX',
#   'LUNCH BOX I LOVE LONDON',
#   'DOG BOWL CHASING BALL DESIGN',
#   'ILLUSTRATED CAT BOWL',
#   'TABLECLOTH RED APPLES DESIGN',
#   'SET OF SALT AND PEPPER TOADSTOOLS'],
#  ['REGENCY CAKESTAND 3 TIER',
#   'BIG DOUGHNUT FRIDGE MAGNETS',
#   'RECIPE BOX BLUE SKETCHBOOK DESIGN',
#   'JAM MAKING SET PRINTED',
#   'JAM MAKING SET WITH JARS',
#   'COFFEE MUG APPLES DESIGN',
#   'COFFEE MUG PEARS  DESIGN',
#   'RED RETROSPOT MINI CASES',
#   "CHILDREN'S CIRCUS PARADE MUG",
#   'CHILDS BREAKFAST SET CIRCUS PARADE',
#   'GIRAFFE WOODEN RULER',
#   'JUMBO BAG WOODLAND ANIMALS',
#   'JUMBO STORAGE BAG SUKI',
#   'WOODLAND CHARLOTTE BAG',
#   'CHARLOTTE BAG SUKI DESIGN',
#   "POPPY'S PLAYHOUSE KITCHEN",
#   'EASTER CRAFT 4 CHICKS',
#   'FELTCRAFT CUSHION OWL',
#   '12 PENCIL SMALL TUBE WOODLAND',
#   'PACK OF 6 HANDBAG GIFT BOXES',
#   'PACK OF 6 BIRDY GIFT TAGS'],
#  ['WRAP POPPIES  DESIGN',
#   'WRAP DOILEY DESIGN',
#   'REVOLVER WOODEN RULER',
#   'SET OF 4 PANTRY JELLY MOULDS',
#   'SET OF 72 PINK HEART PAPER DOILIES',
#   'WOODLAND CHARLOTTE BAG',
#   'SET OF 72 RETROSPOT PAPER  DOILIES',
#   'TV DINNER TRAY DOLLY GIRL',
#   'PENCIL CASE LIFE IS BEAUTIFUL',
#   'RED KITCHEN SCALES',
#   'ALARM CLOCK BAKELIKE PINK',
#   'FUNKY DIVA PEN',
#   'SET OF 3 CAKE TINS PANTRY DESIGN'],
#  ['COLOURING PENCILS BROWN TUBE',
#   'PARTY PIZZA DISH RED RETROSPOT',
#   'POMPOM CURTAIN',
#   'ASSORTED EASTER GIFT TAGS',
#   'EASTER TIN KEEPSAKE',
#   'RED TOADSTOOL LED NIGHT LIGHT',
#   'RETROSPOT TEA SET CERAMIC 11 PC',
#   'RED  HARMONICA IN BOX',
#   'PLASTERS IN TIN CIRCUS PARADE',
#   'PLASTERS IN TIN VINTAGE PAISLEY',
#   'PACK OF 12 RED RETROSPOT TISSUES',
#   'PACK OF 12 HEARTS DESIGN TISSUES',
#   'WRAP RED APPLES',
#   'COFFEE MUG PEARS  DESIGN',
#   'COFFEE MUG APPLES DESIGN',
#   'SET OF 2 TEA TOWELS APPLE AND PEARS',
#   'OVEN MITT APPLES DESIGN',
#   'PACK OF 20 NAPKINS RED APPLES',
#   'RED RETROSPOT SHOPPER BAG',
#   'RETROSPOT RED WASHING UP GLOVES',
#   'RED RETROSPOT OVEN GLOVE DOUBLE',
# ...
#   'MEMO BOARD COTTAGE DESIGN'],
#  ['ROUND SNACK BOXES SET OF4 WOODLAND',
#   'ROUND SNACK BOXES SET OF 4 FRUITS',
#   'JUMBO BAG APPLES',
#   'JUMBO BAG PAISLEY PARK',
#   'SET OF 4 KNICK KNACK TINS LONDON',
#   'SET OF 4 KNICK KNACK TINS LEAF',
#   'VICTORIAN SEWING BOX MEDIUM',
#   'VICTORIAN SEWING BOX LARGE',
#   'PARISIENNE SEWING BOX',
#   '6 RIBBONS RUSTIC CHARM',
#   '6 RIBBONS SHIMMERING PINKS',
#   'TRADITIONAL KNITTING NANCY'],
#  ['SET/10 BLUE POLKADOT PARTY CANDLES',
#   'SET/10 PINK POLKADOT PARTY CANDLES',
#   'SET/10 RED POLKADOT PARTY CANDLES',
#   'SPACEBOY MINI BACKPACK',
#   'PLASTERS IN TIN CIRCUS PARADE',
#   'CIRCUS PARADE CHILDRENS EGG CUP',
#   'CHILDRENS CUTLERY CIRCUS PARADE',
#   'CHILDRENS CUTLERY POLKADOT PINK',
#   'CHILDRENS CUTLERY RETROSPOT RED',
#   'CHILDRENS CUTLERY POLKADOT BLUE',
#   'PLASTERS IN TIN STRONGMAN',
#   'BLUE HARMONICA IN BOX',
#   'PICTURE DOMINOES',
#   'SET 12 KIDS COLOUR  CHALK STICKS',
#   'REVOLVER WOODEN RULER',
#   'GIRAFFE WOODEN RULER',
#   'VINTAGE DONKEY TAIL GAME',
#   'BOX OF VINTAGE ALPHABET BLOCKS',
#   'FANCY FONT BIRTHDAY CARD,',
#   'ELEPHANT BIRTHDAY CARD',
#   'CANDLE HOLDER SILVER MADELINE',
#   'WRAP ALPHABET POSTER',
#   'WRAP CIRCUS PARADE',
#   'FANCY FONTS BIRTHDAY WRAP',
#   'WRAP RED APPLES',
#   'PACK OF 6 BIRDY GIFT TAGS',
#   'CHARLOTTE BAG VINTAGE ALPHABET',
#   'JUMBO BAG ALPHABET',
#   'EMBROIDERED RIBBON REEL DAISY',
#   'RIBBON REEL FLORA + FAUNA',
#   'RIBBON REEL POLKADOTS',
#   'SPOTTY BUNTING',
#   'SET OF 4 PANTRY JELLY MOULDS',
#   'PACK OF 20 NAPKINS PANTRY DESIGN',
#   'PACK OF 20 NAPKINS RED APPLES',
#   'JINGLE BELL HEART ANTIQUE SILVER',
#   'RIBBON REEL MAKING SNOWMEN'],
#  ['3 HOOK HANGER MAGIC GARDEN',
#   '5 HOOK HANGER MAGIC TOADSTOOL',
#   'SET/5 RED RETROSPOT LID GLASS BOWLS',
#   'SET OF SALT AND PEPPER TOADSTOOLS',
#   'DELUXE SEWING KIT',
#   'TRIPLE PHOTO FRAME CORNICE',
#   'RETROSPOT PARTY BAG + STICKER SET',
#   'HOOK, 1 HANGER ,MAGIC GARDEN',
#   '6 RIBBONS RUSTIC CHARM',
#   'CIRCUS PARADE LUNCH BOX',
#   'ORGANISER WOOD ANTIQUE WHITE',
#   'RED SPOTTY BISCUIT TIN',
#   'PORCELAIN HANGING BELL SMALL',
#   'ADVENT CALENDAR GINGHAM SACK'],
#  ['SET 7 BABUSHKA NESTING BOXES'],
#  ['CHILDS BREAKFAST SET CIRCUS PARADE'],
#  ['BLUE PADDED SOFT MOBILE'],
#  ['EASTER TIN CHICKS PINK DAISY', 'EASTER TIN BUNNY BOUQUET'],
#  ['WOODLAND PARTY BAG + STICKER SET',
#   'RETROSPOT PARTY BAG + STICKER SET',
#   '36 FOIL HEART CAKE CASES'],
#  ['CHILDS BREAKFAST SET CIRCUS PARADE', 'GLASS  BEURRE DISH'],
#  ['CHILDS BREAKFAST SET CIRCUS PARADE', 'GLASS  BEURRE DISH'],
#  ['BREAD BIN DINER STYLE IVORY',
#   'MILK PAN RED RETROSPOT',
#   'MILK PAN PINK POLKADOT',
#   'FRYING PAN RED RETROSPOT',
#   'RED TOADSTOOL LED NIGHT LIGHT',
#   'TOADSTOOL MONEY BOX'],
#  ["CHILDREN'S SPACEBOY MUG"],
#  ['ROSE COTTAGE KEEPSAKE BOX',
#   'OVEN MITT APPLES DESIGN',
#   'CERAMIC STRAWBERRY CAKE MONEY BANK',
#   'STRAWBERRY CERAMIC TRINKET BOX',
#   'REGENCY CAKESTAND 3 TIER',
#   'SET/5 RED RETROSPOT LID GLASS BOWLS',
#   'STRAWBERRY CERAMIC TRINKET BOX',
#   'PACK OF 20 NAPKINS RED APPLES',
#   'GIFT BAG BIRTHDAY',
#   'FRIDGE MAGNETS LES ENFANTS ASSORTED',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'PLASTERS IN TIN STRONGMAN',
#   'SAVE THE PLANET COTTON TOTE BAG',
#   'TV DINNER TRAY DOLLY GIRL',
#   'WOODLAND DESIGN  COTTON TOTE BAG'],
#  ['COFFEE MUG DOG + BALL DESIGN',
#   'CHILDS BREAKFAST SET SPACEBOY',
#   'CHILDS BREAKFAST SET CIRCUS PARADE'],
#  ['ROSE COTTAGE KEEPSAKE BOX',
#   '3 PIECE SPACEBOY COOKIE CUTTER SET',
#   'JAM JAR WITH PINK LID',
#   'JAM MAKING SET PRINTED',
#   'FRIDGE MAGNETS LES ENFANTS ASSORTED',
#   'ALARM CLOCK BAKELIKE PINK',
#   'STRAWBERRY FAIRY CAKE TEAPOT',
#   'REGENCY CAKESTAND 3 TIER'],
#  ['SET 20 NAPKINS FAIRY CAKES DESIGN',
#   'EMPIRE TISSUE BOX',
#   '200 BENDY SKULL STRAWS',
#   'SET OF 4 NAPKIN CHARMS CROWNS',
#   'CLOTHES PEGS RETROSPOT PACK 24',
#   'MULTI COLOUR SILVER T-LIGHT HOLDER',
#   'GLASS CLOCHE SMALL',
#   'GLASS CLOCHE LARGE',
#   'WOODEN SKITTLES GARDEN SET'],
#  ['6 RIBBONS RUSTIC CHARM'],
#  ['REGENCY CAKESTAND 3 TIER'],
#  ['SWEETHEART CERAMIC TRINKET BOX'],
#  ['BAKING SET 9 PIECE RETROSPOT',
#   'BAKING SET SPACEBOY DESIGN',
#   'SET/20 RED RETROSPOT PAPER NAPKINS',
#   'PACK OF 20 NAPKINS RED APPLES',
#   'FAIRY CAKE BIRTHDAY CANDLE SET',
#   'JAM MAKING SET WITH JARS'],
#  ['BAKING MOULD CHOCOLATE CUPCAKES',
#   'STRAWBERRY FAIRY CAKE TEAPOT',
#   'REGENCY CAKESTAND 3 TIER'],
#  ['POTTING SHED TWINE',
#   'CARDHOLDER GINGHAM CHRISTMAS TREE',
#   'REGENCY CAKESTAND 3 TIER',
#   'GUMBALL COAT RACK',
#   'SET OF 3 BABUSHKA STACKING TINS',
#   'GLASS  BEURRE DISH',
#   'CHRISTMAS STAR WISH LIST CHALKBOARD',
#   'WOODEN SKITTLES GARDEN SET'],
#  ['DELUXE SEWING KIT',
#   'BAKING SET 9 PIECE RETROSPOT',
#   'SET OF SALT AND PEPPER TOADSTOOLS',
#   'RED RETROSPOT OVEN GLOVE DOUBLE',
#   'LUNCH BOX WITH CUTLERY RETROSPOT',
#   'LARGE HEART MEASURING SPOONS',
#   'SET/10 RED POLKADOT PARTY CANDLES',
#   'SET 12 KIDS COLOUR  CHALK STICKS',
#   'SET 12 KIDS  WHITE CHALK STICKS',
#   'CLOTHES PEGS RETROSPOT PACK 24',
#   'SET 3 RETROSPOT TEA,COFFEE,SUGAR'],
#  ['RED TOADSTOOL LED NIGHT LIGHT', 'CHILDS BREAKFAST SET SPACEBOY'],
#  ['RED RETROSPOT SUGAR JAM BOWL', 'RED GINGHAM ROSE JEWELLERY BOX'],
#  ['REGENCY CAKESTAND 3 TIER'],
#  ['5 HOOK HANGER MAGIC TOADSTOOL',
#   'JAM JAR WITH PINK LID',
#   'PIGGY BANK RETROSPOT',
#   'JAM JAR WITH GREEN LID'],
#  ['KEY CABINET MA CAMPAGNE',
#   '3 HOOK PHOTO SHELF ANTIQUE WHITE',
#   'ORGANISER WOOD ANTIQUE WHITE'],
#  ['CHOCOLATE BOX RIBBONS',
#   'SCANDINAVIAN REDS RIBBONS',
#   'SPACEBOY LUNCH BOX',
#   'GUMBALL COAT RACK',
#   'REGENCY CAKESTAND 3 TIER',
#   'ROUND SNACK BOXES SET OF 4 FRUITS',
#   'ROUND SNACK BOXES SET OF4 WOODLAND',
#   'HOOK, 1 HANGER ,MAGIC GARDEN',
#   '5 HOOK HANGER MAGIC TOADSTOOL',
#   '6 RIBBONS RUSTIC CHARM',
#   'WHITE SPOT BLUE CERAMIC DRAWER KNOB',
#   'WHITE SPOT RED CERAMIC DRAWER KNOB',
#   'RED STRIPE CERAMIC DRAWER KNOB',
#   'BLUE POLKADOT PLATE',
#   'RED RETROSPOT BOWL'],
#  ['STRAWBERRY LUNCH BOX WITH CUTLERY',
#   'PAPER BUNTING RETROSPOT',
#   'PLASTERS IN TIN SPACEBOY',
#   'FOUR HOOK  WHITE LOVEBIRDS'],
#  ['NECKLACE+BRACELET PINK BUTTERFLY', 'JIGSAW TREE WITH BIRDHOUSE'],
#  ['VICTORIAN SEWING BOX LARGE',
#   'CABIN BAG VINTAGE PAISLEY',
#   'TOADSTOOL MONEY BOX',
#   'GLASS  BEURRE DISH',
#   'CABIN BAG VINTAGE RETROSPOT',
#   'MINT KITCHEN SCALES',
#   'REGENCY CAKESTAND 3 TIER',
#   'SET OF 3 BABUSHKA STACKING TINS',
#   'POTTING SHED TWINE'],
#  ['SET 7 BABUSHKA NESTING BOXES',
#   'SET OF 3 CAKE TINS PANTRY DESIGN',
#   'STRAWBERRY FAIRY CAKE TEAPOT',
#   'REGENCY CAKESTAND 3 TIER',
#   'STRAWBERRY CERAMIC TRINKET BOX',
#   'SWEETHEART CERAMIC TRINKET BOX'],
#  ['ROUND SNACK BOXES SET OF 4 FRUITS',
#   'SET OF 3 CAKE TINS PANTRY DESIGN',
#   'BREAD BIN DINER STYLE IVORY'],
#  ['RED KITCHEN SCALES'],
#  ['GUMBALL COAT RACK', '5 HOOK HANGER RED MAGIC TOADSTOOL'],
#  ['BLUE COAT RACK PARIS FASHION',
#   '3 HOOK PHOTO SHELF ANTIQUE WHITE',
#   'WOODEN FRAME ANTIQUE WHITE'],
#  ['RED RETROSPOT CAKE STAND',
#   'REGENCY CAKESTAND 3 TIER',
#   '12 PINK HEN+CHICKS IN BASKET'],
#  ['CHILDRENS APRON SPACEBOY DESIGN',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'DINOSAUR LUNCH BOX WITH CUTLERY',
#   'CAKE STAND 3 TIER MAGIC GARDEN'],
#  ['GYMKHANA TREASURE BOOK BOX', 'TREASURE ISLAND BOOK BOX'],
#  ['PANTRY ROLLING PIN'],
#  ['SET OF 3 CAKE TINS PANTRY DESIGN', 'STRAWBERRY CERAMIC TRINKET BOX'],
#  ['STRAWBERRY CERAMIC TRINKET BOX'],
#  ['EASTER TIN BUNNY BOUQUET', 'HEN HOUSE W CHICK STANDING'],
#  ['GUMBALL COAT RACK',
#   'REGENCY CAKESTAND 3 TIER',
#   'ROUND SNACK BOXES SET OF4 WOODLAND',
#   'GROW YOUR OWN PLANT IN A CAN',
#   'RED TOADSTOOL LED NIGHT LIGHT',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY',
#   'PACK OF 12 STICKY BUNNIES'],
#  ['SET OF 4 PANTRY JELLY MOULDS', 'ROUND CONTAINER SET OF 5 RETROSPOT'],
#  ['CAKE STAND 3 TIER MAGIC GARDEN',
#   'GUMBALL COAT RACK',
#   'FELT FARM ANIMAL RABBIT',
#   'JIGSAW RABBIT AND BIRDHOUSE',
#   'JIGSAW TREE WITH WATERING CAN'],
#  ['BLUE POLKADOT COFFEE MUG'],
#  ["MOTHER'S KITCHEN SPOON REST", 'KNICKERBOCKERGLORY MAGNET ASSORTED'],
#  ['PINK BLUE FELT CRAFT TRINKET BOX'],
#  ['Manual'],
#  ['LARGE CAKE STAND HANGING HEARTS'],
#  ['ROUND SNACK BOXES SET OF 4 FRUITS',
#   'RECIPE BOX RETROSPOT',
#   'GUMBALL COAT RACK',
#   'CHARLOTTE BAG SUKI DESIGN',
#   'WOODLAND STORAGE BOX SMALL',
#   'WOODLAND STORAGE BOX LARGE',
#   'RED RETROSPOT CUP',
#   'WOODLAND CHARLOTTE BAG',
#   'JUMBO BAG WOODLAND ANIMALS'],
#  ['JAM JAR WITH GREEN LID',
#   'JAM JAR WITH PINK LID',
#   'ROUND SNACK BOXES SET OF4 WOODLAND'],
#  ['GUMBALL COAT RACK'],
#  ['GLASS  BEURRE DISH',
#   'GUMBALL COAT RACK',
#   'WOODEN CROQUET GARDEN SET',
#   'RED KITCHEN SCALES'],
#  ['JAM JAR WITH PINK LID'],
#  ['REGENCY CAKESTAND 3 TIER'],
#  ['BREAD BIN DINER STYLE MINT', 'BREAD BIN DINER STYLE IVORY'],
#  ['JUMBO BAG APPLES',
#   'FELTCRAFT GIRL AMELIE KIT',
#   'WATERING CAN BLUE ELEPHANT',
#   'WATERING CAN GREEN DINOSAUR',
#   '3 HOOK HANGER MAGIC GARDEN'],
#  ['JUMBO BAG APPLES',
#   'FELTCRAFT GIRL AMELIE KIT',
#   'WATERING CAN BLUE ELEPHANT',
#   'WATERING CAN GREEN DINOSAUR'],
#  ['PARISIENNE CURIO CABINET'],
#  ['RED RETROSPOT SMALL MILK JUG',
#   'RED RETROSPOT SUGAR JAM BOWL',
#   'ROUND SNACK BOXES SET OF 4 FRUITS',
#   'ROUND SNACK BOXES SET OF4 WOODLAND'],
#  ['CHILDS BREAKFAST SET CIRCUS PARADE', 'CHILDS BREAKFAST SET SPACEBOY'],
#  ['CHARLOTTE BAG SUKI DESIGN', 'STRAWBERRY CHARLOTTE BAG'],
#  ['JUMBO BAG PEARS', 'CHARLOTTE BAG APPLES DESIGN'],
#  ['PLASTERS IN TIN CIRCUS PARADE',
#   'ROUND SNACK BOXES SET OF 4 FRUITS',
#   'SET 12 KIDS COLOUR  CHALK STICKS',
#   'RED RETROSPOT WRAP',
#   '12 PENCILS TALL TUBE WOODLAND',
#   'WRAP RED APPLES',
#   'PACK OF 20 NAPKINS PANTRY DESIGN'],
#  ['GUMBALL COAT RACK'],
#  ['SET OF 3 REGENCY CAKE TINS',
#   'SET OF TEA COFFEE SUGAR TINS PANTRY',
#   'SET OF 4 KNICK KNACK TINS DOILEY',
#   'DOILEY STORAGE TIN'],
#  ['RETRO PLASTIC ELEPHANT TRAY'],
#  ['RETROSPOT PARTY BAG + STICKER SET',
#   'REGENCY CAKESTAND 3 TIER',
#   'GLASS  BEURRE DISH',
#   'WOODEN CROQUET GARDEN SET',
#   'SET/5 RED RETROSPOT LID GLASS BOWLS',
#   'CLASSIC CAFE SUGAR DISPENSER'],
#  ['Manual'],
#  ['JIGSAW TOADSTOOLS 3 PIECE', 'PENNY FARTHING BIRTHDAY CARD'],
#  ['SET OF 4 KNICK KNACK TINS LEAF',
#   'DOILEY STORAGE TIN',
#   'PLASTERS IN TIN CIRCUS PARADE',
#   'GUMBALL COAT RACK',
#   'ENAMEL WATERING CAN CREAM',
#   'RETROSPOT PARTY BAG + STICKER SET',
#   'ROUND SNACK BOXES SET OF4 WOODLAND',
#   'RED SPOT CERAMIC DRAWER KNOB',
#   'BLUE STRIPE CERAMIC DRAWER KNOB'],
#  ['CLASSIC GLASS COOKIE JAR'],
#  ['RED GINGHAM ROSE JEWELLERY BOX'],
#  ['ROUND SNACK BOXES SET OF4 WOODLAND', 'LUNCH BOX WITH CUTLERY RETROSPOT'],
#  ['STRAWBERRY FAIRY CAKE TEAPOT', 'REGENCY CAKESTAND 3 TIER'],
#  ['36 PENCILS TUBE WOODLAND',
#   'COFFEE MUG APPLES DESIGN',
#   'CHILDS BREAKFAST SET SPACEBOY'],
#  ['PARISIENNE SEWING BOX',
#   'DOORMAT RED RETROSPOT',
#   'GLASS  BEURRE DISH',
#   'CABIN BAG VINTAGE RETROSPOT',
#   'Manual'],
#  ['GRASS HOPPER WOODEN WALL CLOCK',
#   'REGENCY CAKESTAND 3 TIER',
#   'ANTIQUE GLASS DRESSING TABLE POT',
#   'RECTANGULAR SHAPED MIRROR',
#   'GLASS  SONGBIRD STORAGE JAR'],
#  ['FAMILY ALBUM WHITE PICTURE FRAME', 'RETROSPOT TEA SET CERAMIC 11 PC'],
#  ['RED REFECTORY CLOCK'],
#  ['3 TRADITIONAl BISCUIT CUTTERS  SET',
#   'CLASSIC GLASS COOKIE JAR',
#   'JAM MAKING SET WITH JARS',
#   'TOADSTOOL MONEY BOX'],
#  ['STRAWBERRY CERAMIC TRINKET BOX'],
#  ['JUMBO BAG APPLES', 'RUBY GLASS CLUSTER BRACELET'],
#  ['RETRO PLASTIC ELEPHANT TRAY',
#   '3 HOOK HANGER MAGIC GARDEN',
#   'RED RETROSPOT PEG BAG'],
#  ['TRAVEL CARD WALLET KEEP CALM',
#   'ENGLISH ROSE HOT WATER BOTTLE',
#   'REGENCY SUGAR BOWL GREEN',
#   'JAM JAR WITH GREEN LID',
#   'PIGGY BANK RETROSPOT',
#   'JAM MAKING SET WITH JARS'],
#  ['TOADSTOOL BEDSIDE LIGHT'],
#  ['PLASTERS IN TIN SKULLS'],
#  ['FRENCH ENAMEL CANDLEHOLDER'],
#  ['SET OF 3 REGENCY CAKE TINS',
#   'TREASURE TIN GYMKHANA DESIGN',
#   'PANTRY MAGNETIC  SHOPPING LIST',
#   'SKETCHBOOK MAGNETIC SHOPPING LIST',
#   'STRAWBERRY CERAMIC TRINKET BOX',
#   'STORAGE TIN VINTAGE DOILY',
#   'REGENCY CAKESTAND 3 TIER'],
#  ['PANTRY SCRUBBING BRUSH',
#   'RECIPE BOX PANTRY YELLOW DESIGN',
#   'RED KITCHEN SCALES',
#   'GLASS  BEURRE DISH'],
#  ['REGENCY TEAPOT ROSES',
#   'REGENCY TEA PLATE PINK',
#   'ROSES REGENCY TEACUP AND SAUCER',
#   'PINK REGENCY TEACUP AND SAUCER',
#   'GREEN REGENCY TEACUP AND SAUCER'],
#  ['KNICKERBOCKERGLORY MAGNET ASSORTED',
#   'RED STRIPE CERAMIC DRAWER KNOB',
#   'DOORMAT RED RETROSPOT'],
#  ['GRASS HOPPER WOODEN WALL CLOCK'],
#  ['SET OF 60 PANTRY DESIGN CAKE CASES',
#   'GLASS  BEURRE DISH',
#   'MINT KITCHEN SCALES'],
#  ['LUNCH BAG SUKI DESIGN'],
#  ['BIRD DECORATION GREEN POLKADOT'],
#  ['RECIPE BOX RETROSPOT', 'RED RETROSPOT PICNIC BAG'],
#  ['PICNIC BOXES SET OF 3 RETROSPOT'],
#  ['SPACEBOY CHILDRENS BOWL'],
#  ['SPACEBOY CHILDRENS CUP'],
#  ['STORAGE TIN VINTAGE DOILY', 'TREASURE TIN GYMKHANA DESIGN'],
#  ['FLAG OF ST GEORGE CHAIR'],
#  ['ROUND SNACK BOXES SET OF 4 FRUITS'],
#  ['HOT WATER BOTTLE KEEP CALM',
#   'FRENCH ENAMEL CANDLEHOLDER',
#   'JAM JAR WITH PINK LID'],
#  ['PANTRY MAGNETIC  SHOPPING LIST'],
#  ['CHARLIE & LOLA WASTEPAPER BIN BLUE',
#   'RED RETROSPOT SUGAR JAM BOWL',
#   'DOLLY GIRL CHILDRENS BOWL',
#   'FOLDING BUTTERFLY MIRROR HOT PINK'],
#  ['PURPLE ENAMEL FLOWER RING', 'PURPLE BOUDICCA LARGE BRACELET'],
#  ['MONEY BOX POCKET MONEY DESIGN',
#   'RED RETROSPOT CUP',
#   'GLASS  BEURRE DISH',
#   'JAM MAKING SET WITH JARS'],
#  ['Manual'],
#  ['RED KITCHEN SCALES'],
#  ['VINTAGE DOILY DELUXE SEWING KIT'],
#  ['REGENCY CAKESTAND 3 TIER', 'PINK GLASS CANDLEHOLDER'],
#  ["CHILDREN'S SPACEBOY MUG",
#   'PLASTERS IN TIN CIRCUS PARADE',
#   'CHILDS BREAKFAST SET CIRCUS PARADE'],
#  ['SET OF 3 REGENCY CAKE TINS',
#   'SET 12 COLOUR PENCILS DOLLY GIRL',
#   'SKETCHBOOK MAGNETIC SHOPPING LIST',
#   'STRAWBERRY CERAMIC TRINKET POT',
#   'SET OF 6 SNACK LOAF BAKING CASES',
#   'SET OF 4 KNICK KNACK TINS LONDON',
#   'REGENCY CAKESTAND 3 TIER',
#   'PANTRY MAGNETIC  SHOPPING LIST'],
#  ['MINT KITCHEN SCALES'],
#  ['WOODEN OWLS LIGHT GARLAND'],
#  ['STOOL HOME SWEET HOME', 'BELLE JARDINIERE CUSHION COVER'],
#  ['VINTAGE DOILY DELUXE SEWING KIT',
#   'GUMBALL COAT RACK',
#   'FOUR HOOK  WHITE LOVEBIRDS',
#   'BLUE STRIPE CERAMIC DRAWER KNOB',
#   'ASSORTED COLOUR MINI CASES',
#   'JUMBO BAG WOODLAND ANIMALS'],
#  ['RED RETROSPOT CAKE STAND',
#   'SET OF 3 CAKE TINS PANTRY DESIGN',
#   'SET OF TEA COFFEE SUGAR TINS PANTRY',
#   'SET OF 3 REGENCY CAKE TINS',
#   'RETRO PLASTIC ELEPHANT TRAY',
#   'LUNCH BOX WITH CUTLERY RETROSPOT',
#   'ROUND SNACK BOXES SET OF4 WOODLAND',
#   'PANTRY ROLLING PIN',
#   'CLOTHES PEGS RETROSPOT PACK 24',
#   'MINI PAINT SET VINTAGE'],
#  ['SET 12 COLOUR PENCILS DOLLY GIRL',
#   'I LOVE LONDON BEAKER',
#   'DOLLY GIRL CHILDRENS CUP',
#   'DOLLY GIRL CHILDRENS BOWL',
#   'SET OF 3 REGENCY CAKE TINS',
#   'SET OF 4 KNICK KNACK TINS DOILY',
#   'PANTRY MAGNETIC  SHOPPING LIST'],
#  ["CHILDREN'S CIRCUS PARADE MUG"],
#  ['RIBBON REEL POLKADOTS', 'RIBBON REEL HEARTS DESIGN'],
#  ['Manual', 'Manual'],
#  ['Manual'],
#  ['PLASTERS IN TIN WOODLAND ANIMALS', 'PLASTERS IN TIN SPACEBOY'],
#  ['PLASTERS IN TIN STRONGMAN', 'PLASTERS IN TIN CIRCUS PARADE'],
#  ['STORAGE TIN VINTAGE DOILY'],
#  ['BOTANICAL GARDENS WALL CLOCK'],
#  ['WOODEN OWLS LIGHT GARLAND', 'GUMBALL COAT RACK'],
#  ['CAKE STAND LOVEBIRD 2 TIER WHITE',
#   'SWEETHEART 3 TIER CAKE STAND',
#   'CAKE STAND 3 TIER MAGIC GARDEN'],
#  ['DELUXE SEWING KIT', 'SET OF 3 REGENCY CAKE TINS'],
#  ['CAKE STAND 3 TIER MAGIC GARDEN',
#   'SWEETHEART 3 TIER CAKE STAND',
#   'CAKE STAND LOVEBIRD 2 TIER WHITE'],
#  ['REGENCY SUGAR BOWL GREEN',
#   'SET OF 3 REGENCY CAKE TINS',
#   'SKETCHBOOK MAGNETIC SHOPPING LIST'],
#  ['BOYS ALPHABET IRON ON PATCHES'],
#  ['CERAMIC CAKE BOWL + HANGING CAKES',
#   'STRAWBERRY FAIRY CAKE TEAPOT',
#   'LIPSTICK PEN RED',
#   'COFFEE MUG APPLES DESIGN',
#   'STRAWBERRY CERAMIC TRINKET POT'],
#  ['SET OF 3 CAKE TINS PANTRY DESIGN', '36 PENCILS TUBE RED RETROSPOT'],
#  ['36 PENCILS TUBE SKULLS', '36 PENCILS TUBE RED RETROSPOT'],
#  ['WOODLAND PARTY BAG + STICKER SET'],
#  ['ANTIQUE SILVER T-LIGHT GLASS',
#   '36 PENCILS TUBE RED RETROSPOT',
#   'STORAGE TIN HOME SWEET HOME',
#   'GLASS JAR DIGESTIVE BISCUITS',
#   'VINTAGE LEAF CHOPPING BOARD',
#   'SET OF 3 REGENCY CAKE TINS',
#   'ROCOCO WALL MIRROR WHITE',
#   'GUMBALL MAGAZINE RACK',
#   'WOOD BLACK BOARD ANT WHITE FINISH',
#   'WOODEN PICTURE FRAME WHITE FINISH',
#   'METAL 4 HOOK HANGER FRENCH CHATEAU',
#   'LARGE HANGING IVORY & RED WOOD BIRD',
#   'SMALL SQUARE CUT GLASS CANDLESTICK']]

# %%
# Find the frequent patterns with support_threshold of 2
start_time = time.time()
patterns = pyfpgrowth.find_frequent_patterns(transactions, 10)
end_time = time.time()
patterns
print(end_time-start_time)
# Out:
# 0.048868656158447266

# %%
# Generate association rules with confidence_threshold of 0.7

rules = pyfpgrowth.generate_association_rules(patterns, 0.5)
rules
# Out:
# {('DINOSAUR PARTY BAG + STICKER SET',): (('WOODLAND PARTY BAG + STICKER SET',),
#   1.0),
#  ('BLUE VINTAGE SPOT BEAKER',): (('PINK VINTAGE SPOT BEAKER',),
#   0.7857142857142857),
#  ('PINK VINTAGE SPOT BEAKER',): (('BLUE VINTAGE SPOT BEAKER',), 1.0),
#  ('DOLLY GIRL CHILDRENS BOWL',): (('DOLLY GIRL CHILDRENS CUP',),
#   0.8571428571428571),
#  ('DOLLY GIRL CHILDRENS CUP',): (('DOLLY GIRL CHILDRENS BOWL',), 1.0),
#  ('BLUE OWL SOFT TOY',): (('PINK OWL SOFT TOY',), 0.6666666666666666),
#  ('PINK OWL SOFT TOY',): (('BLUE OWL SOFT TOY',), 0.7692307692307693),
#  ('BLUE POLKADOT PLATE',): (('BLUE POLKADOT CUP',), 0.7142857142857143),
#  ('STRAWBERRY CHARLOTTE BAG',): (('WOODLAND CHARLOTTE BAG',),
#   0.7142857142857143),
#  ('JUMBO BAG SPACEBOY DESIGN',): (('JUMBO BAG RED RETROSPOT',),
#   0.7857142857142857),
#  ('LUNCH BAG SPACEBOY DESIGN',): (('LUNCH BAG WOODLAND',), 0.7142857142857143),
#  ('CHARLOTTE BAG VINTAGE ALPHABET',): (('ROUND SNACK BOXES SET OF4 WOODLAND',),
#   0.7142857142857143),
#  ('JUMBO BAG PEARS',): (('JUMBO BAG APPLES',), 0.7142857142857143),
#  ('SKETCHBOOK MAGNETIC SHOPPING LIST',): (('PANTRY MAGNETIC  SHOPPING LIST',),
#   0.7142857142857143),
#  ("CHILDREN'S SPACEBOY MUG",): (('ROUND SNACK BOXES SET OF4 WOODLAND',),
#   0.6666666666666666),
#  ('OVEN MITT APPLES DESIGN',): (('PACK OF 20 NAPKINS RED APPLES',),
#   0.6666666666666666),
#  ('BLUE STRIPE CERAMIC DRAWER KNOB',
#   'RED STRIPE CERAMIC DRAWER KNOB'): (('WHITE SPOT RED CERAMIC DRAWER KNOB',), 0.9090909090909091),
#  ('BLUE STRIPE CERAMIC DRAWER KNOB',
#   'WHITE SPOT RED CERAMIC DRAWER KNOB'): (('RED STRIPE CERAMIC DRAWER KNOB',), 0.9090909090909091),
#  ('RED STRIPE CERAMIC DRAWER KNOB',
#   'WHITE SPOT RED CERAMIC DRAWER KNOB'): (('WHITE SPOT BLUE CERAMIC DRAWER KNOB',), 0.625),
#  ('RED SPOT CERAMIC DRAWER KNOB',
#   'RED STRIPE CERAMIC DRAWER KNOB'): (('WHITE SPOT RED CERAMIC DRAWER KNOB',), 0.9090909090909091),
#  ('RED SPOT CERAMIC DRAWER KNOB',
#   'WHITE SPOT RED CERAMIC DRAWER KNOB'): (('RED STRIPE CERAMIC DRAWER KNOB',), 0.8333333333333334),
#  ('ROBOT BIRTHDAY CARD',): (('SPACEBOY BIRTHDAY CARD',), 0.6666666666666666),
#  ('SET/10 PINK POLKADOT PARTY CANDLES',): (('SET/10 RED POLKADOT PARTY CANDLES',),
#   0.6470588235294118),
#  ('SPACEBOY MINI BACKPACK',): (('WOODLAND MINI BACKPACK',),
#   0.6666666666666666),
#  ('WOODLAND MINI BACKPACK',): (('ROUND SNACK BOXES SET OF4 WOODLAND',), 0.55),
#  ('JUMBO BAG PINK POLKADOT',): (('JUMBO BAG RED RETROSPOT',
#    'JUMBO BAG WOODLAND ANIMALS'),
#   0.75),
#  ('JUMBO BAG PINK POLKADOT',
#   'JUMBO BAG RED RETROSPOT'): (('JUMBO BAG WOODLAND ANIMALS',), 0.8),
#  ('JUMBO BAG PINK POLKADOT',
#   'JUMBO BAG WOODLAND ANIMALS'): (('JUMBO BAG RED RETROSPOT',), 1.0),
#  ('JUMBO BAG RED RETROSPOT',
#   'JUMBO BAG WOODLAND ANIMALS'): (('WOODLAND CHARLOTTE BAG',), 0.5),
#  ('ROUND CONTAINER SET OF 5 RETROSPOT',): (('ROUND SNACK BOXES SET OF4 WOODLAND',),
#   0.625),
#  ('SET OF TEA COFFEE SUGAR TINS PANTRY',): (('SET OF 3 REGENCY CAKE TINS',),
#   0.6875),
#  ('STORAGE TIN VINTAGE DOILY',): (('SET OF 3 REGENCY CAKE TINS',), 0.625),
#  ('WOODLAND  STICKERS',): (('ROUND SNACK BOXES SET OF4 WOODLAND',),
#   0.7058823529411765),
#  ('SWEETHEART CERAMIC TRINKET BOX',): (('STRAWBERRY CERAMIC TRINKET BOX',),
#   0.8235294117647058),
#  ('RED STRIPE CERAMIC DRAWER KNOB',
#   'WHITE SPOT BLUE CERAMIC DRAWER KNOB'): (('WHITE SPOT RED CERAMIC DRAWER KNOB',), 1.0),
#  ('WHITE SPOT BLUE CERAMIC DRAWER KNOB',
#   'WHITE SPOT RED CERAMIC DRAWER KNOB'): (('RED STRIPE CERAMIC DRAWER KNOB',),
#   0.7142857142857143),
#  ('SET OF 12 MINI LOAF BAKING CASES',): (('SET OF 6 SNACK LOAF BAKING CASES',),
#   0.631578947368421),
#  ('SET OF 6 SNACK LOAF BAKING CASES',): (('SET OF 12 MINI LOAF BAKING CASES',),
#   0.7058823529411765),
#  ('SCANDINAVIAN REDS RIBBONS',): (('6 RIBBONS RUSTIC CHARM',),
#   0.6363636363636364),
#  ('RED RETROSPOT BOWL',): (('RED RETROSPOT CUP',), 0.6666666666666666),
#  ('JAM JAR WITH GREEN LID',): (('JAM JAR WITH PINK LID',), 0.8947368421052632),
#  ('CHILDRENS APRON APPLES DESIGN',): (('ROUND SNACK BOXES SET OF4 WOODLAND',),
#   0.5263157894736842),
#  ('STRAWBERRY FAIRY CAKE TEAPOT',): (('REGENCY CAKESTAND 3 TIER',),
#   0.5263157894736842),
#  ('3 PIECE SPACEBOY COOKIE CUTTER SET',): (('ROUND SNACK BOXES SET OF4 WOODLAND',),
#   0.5),
#  ('LUNCH BAG RED RETROSPOT',): (('LUNCH BAG WOODLAND',), 0.75),
#  ('WRAP RED APPLES',): (('ROUND SNACK BOXES SET OF4 WOODLAND',), 0.5),
#  ('ROUND SNACK BOXES SET OF4 WOODLAND',
#   'SPACEBOY CHILDRENS BOWL'): (('SPACEBOY CHILDRENS CUP',), 0.8333333333333334),
#  ('ROUND SNACK BOXES SET OF4 WOODLAND',
#   'SPACEBOY CHILDRENS CUP'): (('SPACEBOY CHILDRENS BOWL',), 0.9090909090909091),
#  ('SPACEBOY CHILDRENS BOWL',
#   'SPACEBOY CHILDRENS CUP'): (('ROUND SNACK BOXES SET OF4 WOODLAND',), 0.5882352941176471),
#  ('RED  HARMONICA IN BOX',
#   'ROUND SNACK BOXES SET OF 4 FRUITS'): (('ROUND SNACK BOXES SET OF4 WOODLAND',), 0.8333333333333334),
#  ('RED  HARMONICA IN BOX',
#   'ROUND SNACK BOXES SET OF4 WOODLAND'): (('ROUND SNACK BOXES SET OF 4 FRUITS',), 0.7692307692307693),
#  ('BLUE HARMONICA IN BOX',): (('ROUND SNACK BOXES SET OF4 WOODLAND',),
#   0.6818181818181818),
#  ('BLUE POLKADOT CUP', 'RED RETROSPOT CUP'): (('RED RETROSPOT PLATE',), 0.625),
#  ('BLUE POLKADOT CUP', 'RED RETROSPOT PLATE'): (('RED RETROSPOT CUP',),
#   0.9090909090909091),
#  ('RED RETROSPOT CUP', 'RED RETROSPOT PLATE'): (('BLUE POLKADOT CUP',),
#   0.7142857142857143),
#  ('SET OF 72 RETROSPOT PAPER  DOILIES',): (('PACK OF 72 RETROSPOT CAKE CASES',),
#   0.5238095238095238),
#  ('WOODLAND DESIGN  COTTON TOTE BAG',): (('ROUND SNACK BOXES SET OF4 WOODLAND',),
#   0.5238095238095238),
#  ('BLUE HARMONICA IN BOX',
#   'ROUND SNACK BOXES SET OF 4 FRUITS'): (('ROUND SNACK BOXES SET OF4 WOODLAND',), 1.0),
#  ('BLUE HARMONICA IN BOX',
#   'ROUND SNACK BOXES SET OF4 WOODLAND'): (('ROUND SNACK BOXES SET OF 4 FRUITS',), 0.6666666666666666),
#  ('ROUND SNACK BOXES SET OF 4 FRUITS',
#   'SET OF 2 TEA TOWELS APPLE AND PEARS'): (('ROUND SNACK BOXES SET OF4 WOODLAND',),
#   0.9090909090909091),
#  ('ROUND SNACK BOXES SET OF4 WOODLAND',
#   'SET OF 2 TEA TOWELS APPLE AND PEARS'): (('ROUND SNACK BOXES SET OF 4 FRUITS',),
#   0.7142857142857143),
#  ('CHARLOTTE BAG SUKI DESIGN',
#   'ROUND SNACK BOXES SET OF4 WOODLAND'): (('WOODLAND CHARLOTTE BAG',), 0.9166666666666666),
#  ('CHARLOTTE BAG SUKI DESIGN',
#   'WOODLAND CHARLOTTE BAG'): (('ROUND SNACK BOXES SET OF4 WOODLAND',), 0.6111111111111112),
#  ('JAM MAKING SET WITH JARS',): (('JAM MAKING SET PRINTED',), 0.5),
#  ('SET/20 RED RETROSPOT PAPER NAPKINS',
#   'SET/6 RED SPOTTY PAPER CUPS'): (('SET/6 RED SPOTTY PAPER PLATES',), 0.9090909090909091),
#  ('SET/20 RED RETROSPOT PAPER NAPKINS',
#   'SET/6 RED SPOTTY PAPER PLATES'): (('SET/6 RED SPOTTY PAPER CUPS',), 0.7692307692307693),
#  ('SET/6 RED SPOTTY PAPER PLATES',): (('SET/20 RED RETROSPOT PAPER NAPKINS',),
#   0.5),
#  ('LUNCH BAG APPLE DESIGN',
#   'ROUND SNACK BOXES SET OF 4 FRUITS'): (('ROUND SNACK BOXES SET OF4 WOODLAND',), 0.9230769230769231),
#  ('LUNCH BAG APPLE DESIGN',
#   'ROUND SNACK BOXES SET OF4 WOODLAND'): (('ROUND SNACK BOXES SET OF 4 FRUITS',), 0.75),
#  ('PACK OF 20 NAPKINS RED APPLES',
#   'ROUND SNACK BOXES SET OF 4 FRUITS'): (('ROUND SNACK BOXES SET OF4 WOODLAND',), 0.9166666666666666),
#  ('PACK OF 20 NAPKINS RED APPLES',
#   'ROUND SNACK BOXES SET OF4 WOODLAND'): (('ROUND SNACK BOXES SET OF 4 FRUITS',), 0.6470588235294118),
#  ('RED RETROSPOT MINI CASES',
#   'ROUND SNACK BOXES SET OF 4 FRUITS'): (('ROUND SNACK BOXES SET OF4 WOODLAND',), 0.8333333333333334),
#  ('RED RETROSPOT MINI CASES',
#   'ROUND SNACK BOXES SET OF4 WOODLAND'): (('ROUND SNACK BOXES SET OF 4 FRUITS',), 0.5882352941176471),
#  ('COFFEE MUG APPLES DESIGN',
#   'ROUND SNACK BOXES SET OF 4 FRUITS'): (('ROUND SNACK BOXES SET OF4 WOODLAND',), 0.7692307692307693),
#  ('COFFEE MUG APPLES DESIGN',
#   'ROUND SNACK BOXES SET OF4 WOODLAND'): (('ROUND SNACK BOXES SET OF 4 FRUITS',), 0.6666666666666666),
#  ('CHARLOTTE BAG APPLES DESIGN',
#   'ROUND SNACK BOXES SET OF 4 FRUITS'): (('ROUND SNACK BOXES SET OF4 WOODLAND',), 0.9333333333333333),
#  ('CHARLOTTE BAG APPLES DESIGN',
#   'ROUND SNACK BOXES SET OF4 WOODLAND'): (('ROUND SNACK BOXES SET OF 4 FRUITS',), 0.7777777777777778),
#  ('RED RETROSPOT CHARLOTTE BAG',
#   'SPACEBOY LUNCH BOX'): (('WOODLAND CHARLOTTE BAG',), 1.0),
#  ('SPACEBOY LUNCH BOX',
#   'WOODLAND CHARLOTTE BAG'): (('ROUND SNACK BOXES SET OF4 WOODLAND',),
#   0.6666666666666666),
#  ('RED RETROSPOT CHARLOTTE BAG',
#   'RED TOADSTOOL LED NIGHT LIGHT'): (('WOODLAND CHARLOTTE BAG',), 1.0),
#  ('RED TOADSTOOL LED NIGHT LIGHT',
#   'WOODLAND CHARLOTTE BAG'): (('RED RETROSPOT CHARLOTTE BAG',),
#   0.6470588235294118),
#  ('JUMBO BAG WOODLAND ANIMALS',
#   'RED RETROSPOT CHARLOTTE BAG'): (('WOODLAND CHARLOTTE BAG',), 0.9090909090909091),
#  ('RED RETROSPOT CHARLOTTE BAG',
#   'ROUND SNACK BOXES SET OF4 WOODLAND'): (('WOODLAND CHARLOTTE BAG',), 1.0),
#  ('RED RETROSPOT CHARLOTTE BAG',
#   'WOODLAND CHARLOTTE BAG'): (('ROUND SNACK BOXES SET OF4 WOODLAND',),
#   0.5185185185185185),
#  ('LUNCH BOX WITH CUTLERY RETROSPOT',
#   'ROUND SNACK BOXES SET OF 4 FRUITS'): (('ROUND SNACK BOXES SET OF4 WOODLAND',), 0.8666666666666667),
#  ('LUNCH BOX WITH CUTLERY RETROSPOT',
#   'ROUND SNACK BOXES SET OF4 WOODLAND'): (('ROUND SNACK BOXES SET OF 4 FRUITS',), 0.7222222222222222),
#  ('PLASTERS IN TIN STRONGMAN',
#   'ROUND SNACK BOXES SET OF 4 FRUITS'): (('PLASTERS IN TIN CIRCUS PARADE',), 0.7692307692307693),
#  ('PLASTERS IN TIN STRONGMAN',
#   'ROUND SNACK BOXES SET OF4 WOODLAND'): (('PLASTERS IN TIN CIRCUS PARADE',), 0.7857142857142857),
#  ('PLASTERS IN TIN STRONGMAN',
#   'PLASTERS IN TIN WOODLAND ANIMALS'): (('PLASTERS IN TIN CIRCUS PARADE',), 0.6470588235294118),
#  ('JUMBO BAG RED RETROSPOT',): (('JUMBO BAG WOODLAND ANIMALS',),
#   0.6111111111111112),
#  ('JUMBO BAG RED RETROSPOT',
#   'WOODLAND CHARLOTTE BAG'): (('JUMBO BAG WOODLAND ANIMALS',), 1.0),
#  ('ROUND SNACK BOXES SET OF 4 FRUITS',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY'): (('ROUND SNACK BOXES SET OF4 WOODLAND',),
#   0.8571428571428571),
#  ('ROUND SNACK BOXES SET OF4 WOODLAND',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY'): (('ROUND SNACK BOXES SET OF 4 FRUITS',), 0.5714285714285714),
#  ('GUMBALL COAT RACK',
#   'ROUND SNACK BOXES SET OF 4 FRUITS'): (('ROUND SNACK BOXES SET OF4 WOODLAND',), 0.7333333333333333),
#  ('GUMBALL COAT RACK',
#   'ROUND SNACK BOXES SET OF4 WOODLAND'): (('ROUND SNACK BOXES SET OF 4 FRUITS',), 0.5789473684210527),
#  ('PLASTERS IN TIN CIRCUS PARADE',
#   'RED TOADSTOOL LED NIGHT LIGHT'): (('PLASTERS IN TIN WOODLAND ANIMALS',), 0.8333333333333334),
#  ('PLASTERS IN TIN WOODLAND ANIMALS',
#   'RED TOADSTOOL LED NIGHT LIGHT'): (('ROUND SNACK BOXES SET OF4 WOODLAND',), 0.625),
#  ('6 RIBBONS RUSTIC CHARM',
#   'ROUND SNACK BOXES SET OF4 WOODLAND'): (('ROUND SNACK BOXES SET OF 4 FRUITS',), 0.6470588235294118),
#  ('6 RIBBONS RUSTIC CHARM',
#   'SPACEBOY LUNCH BOX'): (('ROUND SNACK BOXES SET OF4 WOODLAND',), 0.9090909090909091),
#  ('ROUND SNACK BOXES SET OF 4 FRUITS',
#   'SPACEBOY LUNCH BOX'): (('ROUND SNACK BOXES SET OF4 WOODLAND',), 0.9473684210526315),
#  ('ROUND SNACK BOXES SET OF4 WOODLAND',
#   'SPACEBOY LUNCH BOX'): (('ROUND SNACK BOXES SET OF 4 FRUITS',), 0.5454545454545454),
#  ('6 RIBBONS RUSTIC CHARM',
#   'ROUND SNACK BOXES SET OF 4 FRUITS'): (('ROUND SNACK BOXES SET OF4 WOODLAND',), 0.9166666666666666),
#  ('PLASTERS IN TIN WOODLAND ANIMALS',
#   'ROUND SNACK BOXES SET OF 4 FRUITS'): (('ROUND SNACK BOXES SET OF4 WOODLAND',), 0.8636363636363636),
#  ('PLASTERS IN TIN CIRCUS PARADE',
#   'PLASTERS IN TIN SPACEBOY'): (('PLASTERS IN TIN WOODLAND ANIMALS',), 0.7272727272727273),
#  ('PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN WOODLAND ANIMALS'): (('PLASTERS IN TIN CIRCUS PARADE',), 0.5517241379310345),
#  ('PLASTERS IN TIN CIRCUS PARADE',
#   'PLASTERS IN TIN WOODLAND ANIMALS'): (('ROUND SNACK BOXES SET OF4 WOODLAND',), 0.5806451612903226),
#  ('PLASTERS IN TIN CIRCUS PARADE',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'ROUND SNACK BOXES SET OF 4 FRUITS'): (('ROUND SNACK BOXES SET OF4 WOODLAND',),
#   0.9230769230769231),
#  ('PLASTERS IN TIN CIRCUS PARADE',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'ROUND SNACK BOXES SET OF4 WOODLAND'): (('ROUND SNACK BOXES SET OF 4 FRUITS',),
#   0.6666666666666666),
#  ('PLASTERS IN TIN CIRCUS PARADE',
#   'ROUND SNACK BOXES SET OF 4 FRUITS',
#   'ROUND SNACK BOXES SET OF4 WOODLAND'): (('PLASTERS IN TIN WOODLAND ANIMALS',),
#   0.631578947368421),
#  ('PLASTERS IN TIN WOODLAND ANIMALS',
#   'ROUND SNACK BOXES SET OF 4 FRUITS',
#   'ROUND SNACK BOXES SET OF4 WOODLAND'): (('PLASTERS IN TIN CIRCUS PARADE',),
#   0.631578947368421),
#  ('PLASTERS IN TIN CIRCUS PARADE',
#   'ROUND SNACK BOXES SET OF4 WOODLAND'): (('PLASTERS IN TIN WOODLAND ANIMALS',), 0.6666666666666666),
#  ('PLASTERS IN TIN WOODLAND ANIMALS',
#   'ROUND SNACK BOXES SET OF4 WOODLAND'): (('ROUND SNACK BOXES SET OF 4 FRUITS',), 0.5588235294117647),
#  ('ROUND SNACK BOXES SET OF 4 FRUITS',
#   'WOODLAND CHARLOTTE BAG'): (('ROUND SNACK BOXES SET OF4 WOODLAND',), 0.8181818181818182),
#  ('ROUND SNACK BOXES SET OF4 WOODLAND',
#   'WOODLAND CHARLOTTE BAG'): (('ROUND SNACK BOXES SET OF 4 FRUITS',), 0.6206896551724138),
#  ('REGENCY CAKESTAND 3 TIER',
#   'ROUND SNACK BOXES SET OF 4 FRUITS'): (('ROUND SNACK BOXES SET OF4 WOODLAND',), 0.8333333333333334),
#  ('REGENCY CAKESTAND 3 TIER',
#   'ROUND SNACK BOXES SET OF4 WOODLAND'): (('ROUND SNACK BOXES SET OF 4 FRUITS',), 0.5),
#  ('ROUND SNACK BOXES SET OF4 WOODLAND',): (('ROUND SNACK BOXES SET OF 4 FRUITS',),
#   0.5210084033613446)}
